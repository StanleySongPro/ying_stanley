# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %%
source = requests.get("https://www.gv.com.sg/#/")

# %%
soup = BeautifulSoup(source.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en" xml:lang="en">
#  <head>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="all" name="robots"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="utf-8" http-equiv="encoding"/>
#   <meta content="492913240911783" property="fb:app_id"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.gv.com.sg" property="og:url"/>
#   <meta content="https://media.gv.com.sg/cms/resources/templating-kit/themes/gv/images/gg-img.jpg" property="og:image"/>
#   <meta content="Golden Village - New movies in Singapore" property="og:title"/>
#   <meta content="" property="og:description"/>
#   <title>
#    Golden Village - New movies in Singapore
#   </title>
# ...

# %%
nam = soup.find("div", class_="caption")
print(nam)
# Out:
# <div class="caption">
# <h5>{{movie.filmTitle}}</h5>
# <p class="caption-pg" ng-show="movie.rating.length&gt;0">({{movie.rating}}<span ng-show="movie.consumerAdvise.length&gt;0">: {{movie.consumerAdvise}}</span>)</p>
# <p class="caption-times" ng-show="movie.duration&gt;0">{{movie.duration}} minutes</p>
# <ul class="rating list-unstyled list-inline">
# <li ng-repeat="n in [] | range:movie.reviewRating">
# <a ng-click="showReview(movie)"><img ng-if="n == 0 || n &gt;= 1 " ng-src="https://media.gv.com.sg/cms/resources/templating-kit/themes/gv/images/pn-se-1-small.png"/></a>
# <a ng-click="showReview(movie)"><img ng-if="n &lt; 1 &amp;&amp; n != 0" ng-src="https://media.gv.com.sg/cms/resources/templating-kit/themes/gv/images/pn-se-2-small.png"/></a>
# </li>
# </ul>
# <div class="dropdown">
# <div ng-if="movie.isSubFormatExist &amp;&amp; movie.buyTicket">
# <p>Select a format</p>
# ...
