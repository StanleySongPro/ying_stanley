# %% [markdown]
# #### check which packages are outdated
# * pip --outdated
# #### or can use to check which are old packages
# * pip -o
#
# #### update all packages which are outdated
# * pip freeze --local | grep -v '^\-e' | cut -d = -f 1 | xargs -n1 pip install -U

# %% [markdown]
# ### Python Tutorial: virtualenv and why you should use virtual environments
# #### you can separate differnent python enviornment

# %%
# !which python3
# Out:
# /Users/olivia/anaconda3/bin/python3

# %%
# !which pip
# Out:
# /Users/olivia/anaconda3/bin/pip

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -----------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.2
# appnope                            0.1.0
# appscript                          1.0.1
# asn1crypto                         1.3.0
# astroid                            2.3.3
# astropy                            4.0
# atomicwrites                       1.3.0
# attrs                              19.3.0
# Babel                              2.8.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.8.2
# bitarray                           0.8.3
# bkcharts                           0.2
# bleach                             3.1.1
# bokeh                              1.4.0
# boto                               2.49.0
# ...

# %%
# !pip freeze --local > requirment.txt

# %%
# !cat requirment.txt
# Out:
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.7
# anaconda-project==0.8.2
# appnope==0.1.0
# appscript==1.0.1
# asn1crypto==1.3.0
# astroid==2.3.3
# astropy==4.0
# atomicwrites==1.3.0
# attrs==19.3.0
# Babel==2.8.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.8.2
# bitarray==0.8.3
# bkcharts==0.2
# bleach==3.1.1
# bokeh==1.4.0
# boto==2.49.0
# Bottleneck==1.2.1
# certifi==2019.3.9
# cffi==1.14.0
# chardet==3.0.4
# Click==7.0
# cloudpickle==1.3.0
# clyent==1.2.2
# colorama==0.4.3
# conda==4.8.2
# conda-build==3.17.8
# conda-package-handling==1.6.0
# conda-verify==3.1.1
# contextlib2==0.6.0.post1
# coverage==5.0.3
# cryptography==2.8
# cycler==0.10.0
# Cython==0.29.15
# cytoolz==0.9.0.1
# dask==2.11.0
# decorator==4.4.1
# defusedxml==0.6.0
# distributed==2.11.0
# docutils==0.14
# entrypoints==0.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# filelock==3.0.12
# Flask==1.1.1
# future==0.18.2
# gevent==1.4.0
# ...

# %%
# make a virtual environment
# !virtualenv -p /user/bin/python2.6 py26_env
# Out:
# RuntimeError: failed to find interpreter for Builtin discover of python_spec='/user/bin/python2.6'

# %%
# python3 -m venv venv, make a virtaul environment
# source venv/bin/activate : activate the lvirtual environment
# pip list : check what do you have in the virtual environment
# pip install pandas : install package
# pip freeze > requirements.txt : export all the package in this virtual envirnment to 'requirement.txt'
# pip install -r requirements.txt : recursively install all the packages in 'requirments.txt'
# deactivate : deactivate the virtual environment
