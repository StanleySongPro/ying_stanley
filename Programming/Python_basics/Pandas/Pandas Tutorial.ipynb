# %% [markdown]
# # Pandas Tutorial
# ## Python Pandas Tutorial (Part 1): Getting Started with Data Analysis - Installation and Loading Data
# * link https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS
# * code https://www.youtube.com/watch?v=ZyhVh-qRZPA&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS
# * Virtual Environment Tutorial - https://youtu.be/Kg1Yvry_Ydk
# * Jupyter Tutorial - https://youtu.be/HW29067qVWk
# * StackOverflow Survey Download Page - http://bit.ly/SO-Survey-Download

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88873  OSS is, on average, of LOWER quality than prop...
# 88874  OSS is, on average, of HIGHER quality than pro...
# 88875  OSS is, on average, of HIGHER quality than pro...
# 88876  OSS is, on average, of HIGHER quality than pro...
# 88877  The quality of OSS and closed source software ...
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment        Country  \
# 88873                                                NaN            NaN
# 88874                                 Employed full-time            NaN
# 88875                                 Employed part-time       Pakistan
# 88876                                 Employed full-time          Spain
# 88877                 Not employed, but looking for work  United States
# 88878             Not employed, and not looking for work         Canada
# 88879                                                NaN            NaN
# 88880                                 Employed full-time            NaN
# 88881  Independent contractor, freelancer, or self-em...            NaN
# 88882             Not employed, and not looking for work          Spain
#
#               Student                                            EdLevel  \
# 88873             NaN                                                NaN
# 88874             NaN                                                NaN
# 88875             NaN  Secondary school (e.g. American high school, G...
# 88876              No  Secondary school (e.g. American high school, G...
# 88877              No  Some college/university study without earning ...
# 88878              No                          Primary/elementary school
# 88879             NaN                                                NaN
# 88880             NaN                                                NaN
# 88881             NaN                                                NaN
# 88882  Yes, full-time                 Professional degree (JD, MD, etc.)
#
#                                           UndergradMajor  ...  \
# 88873                                                NaN  ...
# 88874                                                NaN  ...
# 88875                                                NaN  ...
# 88876                                                NaN  ...
# 88877  Computer science, computer engineering, or sof...  ...
# 88878                                                NaN  ...
# 88879                                                NaN  ...
# 88880                                                NaN  ...
# 88881                                                NaN  ...
# 88882  Computer science, computer engineering, or sof...  ...
#
#                                            WelcomeChange  \
# 88873                                                NaN
# 88874                                                NaN
# 88875  Not applicable - I did not use Stack Overflow ...
# 88876                                                NaN
# 88877            Just as welcome now as I felt last year
# 88878                                                NaN
# 88879                                                NaN
# 88880                                                NaN
# 88881                                                NaN
# 88882           Somewhat less welcome now than last year
#
#                                             SONewContent   Age Gender Trans  \
# 88873                                                NaN   NaN    NaN   NaN
# 88874                                                NaN   NaN    NaN   NaN
# 88875       Courses on technologies you're interested in   NaN    Man    No
# 88876  Tech articles written by other developers;Indu...  40.0    Man    No
# 88877                                                NaN   NaN    Man    No
# 88878  Tech articles written by other developers;Tech...   NaN    Man    No
# 88879                                                NaN   NaN    NaN   NaN
# 88880                                                NaN   NaN    NaN   NaN
# 88881                                                NaN   NaN    NaN   NaN
# 88882  Tech articles written by other developers;Indu...  18.0    Man    No
#
#                      Sexuality  \
# 88873                      NaN
# 88874                      NaN
# 88875  Straight / Heterosexual
# 88876  Straight / Heterosexual
# 88877  Straight / Heterosexual
# 88878                      NaN
# 88879                      NaN
# 88880                      NaN
# 88881                      NaN
# 88882  Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 88873                                                NaN        NaN
# 88874                                                NaN        NaN
# 88875                                                NaN        Yes
# 88876                       White or of European descent         No
# 88877                                                NaN         No
# 88878                                                NaN         No
# 88879                                                NaN        NaN
# 88880                                                NaN        NaN
# 88881                                                NaN        NaN
# 88882  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 88873                    NaN                         NaN
# 88874                    NaN                         NaN
# 88875              Too short  Neither easy nor difficult
# 88876  Appropriate in length                        Easy
# 88877              Too short  Neither easy nor difficult
# 88878  Appropriate in length                        Easy
# 88879                    NaN                         NaN
# 88880                    NaN                         NaN
# 88881                    NaN                         NaN
# 88882  Appropriate in length                        Easy
#
# [10 rows x 85 columns]

# %%
df.shape
# Out:
# (88883, 85)

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# 11                 OrgSize  Approximately how many people are employed by ...
# 12                 DevType  Which of the following describe you? Please se...
# 13               YearsCode  Including any education, how many years have y...
# 14              Age1stCode  At what age did you write your first line of c...
# 15            YearsCodePro  How many years have you coded professionally (...
# 16               CareerSat  Overall, how satisfied are you with your caree...
# 17                  JobSat  How satisfied are you with your current job? (...
# 18                MgrIdiot  How confident are you that your manager knows ...
# 19                MgrMoney  Do you believe that you need to be a manager t...
# 20                 MgrWant  Do you want to become a manager yourself in th...
# 21                 JobSeek  Which of the following best describes your cur...
# 22            LastHireDate  When was the last time that you took a job wit...
# 23                 LastInt  In your most recent successful job interview (...
# 24                FizzBuzz  Have you ever been asked to solve FizzBuzz in ...
# 25              JobFactors  Imagine that you are deciding between two job ...
# 26            ResumeUpdate  Think back to the last time you updated your r...
# 27          CurrencySymbol  Which currency do you use day-to-day? If your ...
# 28            CurrencyDesc  Which currency do you use day-to-day? If your ...
# 29               CompTotal  What is your current total compensation (salar...
# 30                CompFreq   Is that compensation weekly, monthly, or yearly?
# 31           ConvertedComp  Salary converted to annual USD salaries using ...
# 32             WorkWeekHrs   On average, how many hours per week do you work?
# 33                WorkPlan            How structured or planned is your work?
# 34           WorkChallenge  Of these options, what are your greatest chall...
# 35              WorkRemote                    How often do you work remotely?
# 36                 WorkLoc                    Where would you prefer to work?
# 37                  ImpSyn  For the specific work you do, and the years of...
# 38                 CodeRev           Do you review code as part of your work?
# 39              CodeRevHrs  On average, how many hours per week do you spe...
# 40               UnitTests  Does your company regularly employ unit tests ...
# 41             PurchaseHow  How does your company make decisions about pur...
# 42            PurchaseWhat  What level of influence do you, personally, ha...
# 43      LanguageWorkedWith  Which of the following programming, scripting,...
# 44  LanguageDesireNextYear  Which of the following programming, scripting,...
# 45      DatabaseWorkedWith  Which of the following database environments h...
# 46  DatabaseDesireNextYear  Which of the following database environments h...
# 47      PlatformWorkedWith  Which of the following platforms have you done...
# 48  PlatformDesireNextYear  Which of the following platforms have you done...
# 49      WebFrameWorkedWith  Which of the following web frameworks have you...
# 50  WebFrameDesireNextYear  Which of the following web frameworks have you...
# 51      MiscTechWorkedWith  Which of the following other frameworks, libra...
# 52  MiscTechDesireNextYear  Which of the following other frameworks, libra...
# 53              DevEnviron  Which development environment(s) do you use re...
# 54                   OpSys  What is the primary operating system in which ...
# 55              Containers  How do you use containers (Docker, Open Contai...
# 56           BlockchainOrg  How is your organization thinking about or imp...
# 57            BlockchainIs  Blockchain / cryptocurrency technology is prim...
# 58              BetterLife  Do you think people born today will have a bet...
# 59                ITperson   Are you the "IT support person" for your family?
# 60                   OffOn        Have you tried turning it off and on again?
# 61             SocialMedia        What social media site do you use the most?
# 62            Extraversion    Do you prefer online chat or IRL conversations?
# 63              ScreenName                               What do you call it?
# 64              SOVisit1st  To the best of your memory, when did you first...
# 65             SOVisitFreq  How frequently would you say you visit Stack O...
# 66               SOVisitTo  I visit Stack Overflow to... (check all that a...
# 67            SOFindAnswer  On average, how many times a week do you find ...
# 68             SOTimeSaved  Think back to the last time you solved a codin...
# 69           SOHowMuchTime  About how much time did you save? If you're no...
# 70               SOAccount              Do you have a Stack Overflow account?
# 71              SOPartFreq  How frequently would you say you participate i...
# 72                  SOJobs  Have you ever used or visited Stack Overflow J...
# 73                EntTeams  Have you ever used Stack Overflow for Enterpri...
# 74                  SOComm  Do you consider yourself a member of the Stack...
# 75           WelcomeChange  Compared to last year, how welcome do you feel...
# 76            SONewContent  Would you like to see any of the following on ...
# 77                     Age  What is your age (in years)? If you prefer not...
# 78                  Gender  Which of the following do you currently identi...
# 79                   Trans                    Do you identify as transgender?
# 80               Sexuality  Which of the following do you currently identi...
# 81               Ethnicity  Which of the following do you identify as? Ple...
# 82              Dependents  Do you have any dependents (e.g., children, el...
# 83            SurveyLength  How do you feel about the length of the survey...
# 84              SurveyEase  How easy or difficult was this survey to compl...

# %%
pd
# Out:
# <module 'pandas' from '/Users/olivia/anaconda3/lib/python3.7/site-packages/pandas/__init__.py'>

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# DevType                 Which of the following describe you? Please se...
# YearsCode               Including any education, how many years have y...
# Age1stCode              At what age did you write your first line of c...
# YearsCodePro            How many years have you coded professionally (...
# CareerSat               Overall, how satisfied are you with your caree...
# JobSat                  How satisfied are you with your current job? (...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# JobSeek                 Which of the following best describes your cur...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# JobFactors              Imagine that you are deciding between two job ...
# ResumeUpdate            Think back to the last time you updated your r...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CompTotal               What is your current total compensation (salar...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# ConvertedComp           Salary converted to annual USD salaries using ...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkPlan                          How structured or planned is your work?
# WorkChallenge           Of these options, what are your greatest chall...
# WorkRemote                                How often do you work remotely?
# WorkLoc                                   Where would you prefer to work?
# ImpSyn                  For the specific work you do, and the years of...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# UnitTests               Does your company regularly employ unit tests ...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# DatabaseWorkedWith      Which of the following database environments h...
# DatabaseDesireNextYear  Which of the following database environments h...
# PlatformWorkedWith      Which of the following platforms have you done...
# PlatformDesireNextYear  Which of the following platforms have you done...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# DevEnviron              Which development environment(s) do you use re...
# OpSys                   What is the primary operating system in which ...
# Containers              How do you use containers (Docker, Open Contai...
# BlockchainOrg           How is your organization thinking about or imp...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BetterLife              Do you think people born today will have a bet...
# ITperson                 Are you the "IT support person" for your family?
# OffOn                         Have you tried turning it off and on again?
# SocialMedia                   What social media site do you use the most?
# Extraversion              Do you prefer online chat or IRL conversations?
# ScreenName                                           What do you call it?
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# SOFindAnswer            On average, how many times a week do you find ...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOAccount                           Do you have a Stack Overflow account?
# SOPartFreq              How frequently would you say you participate i...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# SOComm                  Do you consider yourself a member of the Stack...
# WelcomeChange           Compared to last year, how welcome do you feel...
# SONewContent            Would you like to see any of the following on ...
# Age                     What is your age (in years)? If you prefer not...
# Gender                  Which of the following do you currently identi...
# Trans                                     Do you identify as transgender?
# Sexuality               Which of the following do you currently identi...
# Ethnicity               Which of the following do you identify as? Ple...
# Dependents              Do you have any dependents (e.g., children, el...
# SurveyLength            How do you feel about the length of the survey...
# SurveyEase              How easy or difficult was this survey to compl...

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# Country                         In which country do you currently reside?
# CurrencyDesc            Which currency do you use day-to-day? If your ...
# CurrencySymbol          Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear  Which of the following database environments h...
# DatabaseWorkedWith      Which of the following database environments h...
# Dependents              Do you have any dependents (e.g., children, el...
# DevEnviron              Which development environment(s) do you use re...
# DevType                 Which of the following describe you? Please se...
# EdLevel                 Which of the following best describes the high...
# EduOther                Which of the following types of non-degree edu...
# Employment              Which of the following best describes your cur...
# EntTeams                Have you ever used Stack Overflow for Enterpri...
# Ethnicity               Which of the following do you identify as? Ple...
# Extraversion              Do you prefer online chat or IRL conversations?
# FizzBuzz                Have you ever been asked to solve FizzBuzz in ...
# Gender                  Which of the following do you currently identi...
# Hobbyist                                          Do you code as a hobby?
# ITperson                 Are you the "IT support person" for your family?
# ImpSyn                  For the specific work you do, and the years of...
# JobFactors              Imagine that you are deciding between two job ...
# JobSat                  How satisfied are you with your current job? (...
# JobSeek                 Which of the following best describes your cur...
# LanguageDesireNextYear  Which of the following programming, scripting,...
# LanguageWorkedWith      Which of the following programming, scripting,...
# LastHireDate            When was the last time that you took a job wit...
# LastInt                 In your most recent successful job interview (...
# MainBranch              Which of the following options best describes ...
# MgrIdiot                How confident are you that your manager knows ...
# MgrMoney                Do you believe that you need to be a manager t...
# MgrWant                 Do you want to become a manager yourself in th...
# MiscTechDesireNextYear  Which of the following other frameworks, libra...
# MiscTechWorkedWith      Which of the following other frameworks, libra...
# OffOn                         Have you tried turning it off and on again?
# OpSys                   What is the primary operating system in which ...
# OpenSource              How do you feel about the quality of open sour...
# OpenSourcer                   How often do you contribute to open source?
# OrgSize                 Approximately how many people are employed by ...
# PlatformDesireNextYear  Which of the following platforms have you done...
# PlatformWorkedWith      Which of the following platforms have you done...
# PurchaseHow             How does your company make decisions about pur...
# PurchaseWhat            What level of influence do you, personally, ha...
# Respondent              Randomized respondent ID number (not in order ...
# ResumeUpdate            Think back to the last time you updated your r...
# SOAccount                           Do you have a Stack Overflow account?
# SOComm                  Do you consider yourself a member of the Stack...
# SOFindAnswer            On average, how many times a week do you find ...
# SOHowMuchTime           About how much time did you save? If you're no...
# SOJobs                  Have you ever used or visited Stack Overflow J...
# SONewContent            Would you like to see any of the following on ...
# SOPartFreq              How frequently would you say you participate i...
# SOTimeSaved             Think back to the last time you solved a codin...
# SOVisit1st              To the best of your memory, when did you first...
# SOVisitFreq             How frequently would you say you visit Stack O...
# SOVisitTo               I visit Stack Overflow to... (check all that a...
# ScreenName                                           What do you call it?
# Sexuality               Which of the following do you currently identi...
# SocialMedia                   What social media site do you use the most?
# Student                 Are you currently enrolled in a formal, degree...
# SurveyEase              How easy or difficult was this survey to compl...
# SurveyLength            How do you feel about the length of the survey...
# Trans                                     Do you identify as transgender?
# UndergradMajor          What was your main or most important field of ...
# UnitTests               Does your company regularly employ unit tests ...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WorkChallenge           Of these options, what are your greatest chall...
# WorkLoc                                   Where would you prefer to work?
# WorkPlan                          How structured or planned is your work?
# WorkRemote                                How often do you work remotely?
# WorkWeekHrs              On average, how many hours per week do you work?
# YearsCode               Including any education, how many years have y...
# YearsCodePro            How many years have you coded professionally (...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt
# Out:
# Respondent
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8         True
# 9         True
# 10        True
# 11       False
# 12        True
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18        True
# 19       False
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 25       False
# 26        True
# 27        True
# 28       False
# 29       False
# 30       False
# 31        True
# 32        True
# 33        True
# 34       False
# 35       False
# 36        True
# 37        True
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
#          ...
# 82789     True
# 82805    False
# 83000    False
# 83397     True
# 83511    False
# 83612    False
# 83648    False
# 83709     True
# 83777    False
# 83786    False
# 83800    False
# 83862    False
# 84299     True
# 84539     True
# 85182    False
# 85208    False
# 85396    False
# 85538    False
# 85642    False
# 85738     True
# 85744    False
# 85955    False
# 85961    False
# 86012    False
# 86566     True
# 86638    False
# 86806    False
# 86980    False
# 86999    False
# 87352    False
# 87386    False
# 87739     True
# 88062    False
# 88076    False
# 88182    False
# 88212     True
# 88282    False
# 88377    False
# 88601    False
# 88802    False
# 88816    False
# 88863    False
# Name: LanguageWorkedWith, Length: 88883, dtype: bool

# %%
df.loc[filt]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 12                     I am a student who is learning to code       No
# 18          I am not primarily a developer, but I write co...      Yes
# 20          I am not primarily a developer, but I write co...       No
# 21                                I code primarily as a hobby      Yes
# 22                             I am a developer by profession      Yes
# 23                             I am a developer by profession      Yes
# 26                             I am a developer by profession      Yes
# 27          I used to be a developer by profession, but no...      Yes
# 31                     I am a student who is learning to code       No
# 32                             I am a developer by profession       No
# 33                             I am a developer by profession       No
# 36                             I am a developer by profession      Yes
# 37                                I code primarily as a hobby      Yes
# 45          I am not primarily a developer, but I write co...      Yes
# 46                             I am a developer by profession      Yes
# 49                             I am a developer by profession      Yes
# 50                             I am a developer by profession      Yes
# 51                     I am a student who is learning to code      Yes
# 52                             I am a developer by profession      Yes
# 54                             I am a developer by profession      Yes
# 55                     I am a student who is learning to code      Yes
# 57          I am not primarily a developer, but I write co...      Yes
# 60                             I am a developer by profession      Yes
# 61                             I am a developer by profession      Yes
# 62                             I am a developer by profession      Yes
# 63                             I am a developer by profession      Yes
# 67          I am not primarily a developer, but I write co...       No
# 68                             I am a developer by profession      Yes
# 71                             I am a developer by profession      Yes
# 74                             I am a developer by profession      Yes
# 78                             I am a developer by profession       No
# 80                             I am a developer by profession      Yes
# 81                             I am a developer by profession      Yes
# 82                             I am a developer by profession      Yes
# 85                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 61753                                                     NaN       No
# 61787                                                     NaN      Yes
# 61922                                                     NaN      Yes
# 62177                                                     NaN      Yes
# 62999                                                     NaN      Yes
# 63462                                                     NaN       No
# 64998                                                     NaN      Yes
# 65265                                                     NaN      Yes
# 65296                                                     NaN       No
# 66751                                                     NaN      Yes
# 66972                                                     NaN      Yes
# 67206                                                     NaN      Yes
# 68208                                                     NaN      Yes
# 68525                                                     NaN      Yes
# 69366                                                     NaN       No
# 69741                                                     NaN      Yes
# 70630                                                     NaN       No
# 70746                                                     NaN      Yes
# 70985                                                     NaN      Yes
# 71160                                                     NaN      Yes
# 71874                                                     NaN      Yes
# 72325                                                     NaN      Yes
# 72492                                                     NaN      Yes
# 75496                                                     NaN      Yes
# 75974                                                     NaN      Yes
# 77968                                                     NaN       No
# 78292                                                     NaN       No
# 78741                                                     NaN      Yes
# 79795                                                     NaN      Yes
# 79798                                                     NaN      Yes
# 81934                                                     NaN      Yes
# 81994                                                     NaN      Yes
# 82007                                                     NaN       No
# 82789                                                     NaN      Yes
# 83397                                                     NaN      Yes
# 83709                                                     NaN      Yes
# 84299                                                     NaN      Yes
# 84539                                                     NaN      Yes
# 85738                                                     NaN      Yes
# 86566                                                     NaN      Yes
# 87739                                                     NaN      Yes
# 88212                                                     NaN       No
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# 4                                                       Never
# 5                                  Once a month or more often
# 8                                     Less than once per year
# 9                                  Once a month or more often
# 10                                 Once a month or more often
# 12                                                      Never
# 18          Less than once a month but more than once per ...
# 20                                                      Never
# 21                                 Once a month or more often
# 22                                    Less than once per year
# 23                                    Less than once per year
# 26                                    Less than once per year
# 27                                    Less than once per year
# 31                                                      Never
# 32                                                      Never
# 33          Less than once a month but more than once per ...
# 36          Less than once a month but more than once per ...
# 37                                    Less than once per year
# 45                                                      Never
# 46                                    Less than once per year
# 49                                    Less than once per year
# 50                                 Once a month or more often
# 51                                                      Never
# 52                                 Once a month or more often
# 54                                 Once a month or more often
# 55          Less than once a month but more than once per ...
# 57                                                      Never
# 60          Less than once a month but more than once per ...
# 61                                    Less than once per year
# 62          Less than once a month but more than once per ...
# 63          Less than once a month but more than once per ...
# 67                                                      Never
# 68          Less than once a month but more than once per ...
# 71                                                      Never
# 74                                                      Never
# 78          Less than once a month but more than once per ...
# 80          Less than once a month but more than once per ...
# 81          Less than once a month but more than once per ...
# 82                                 Once a month or more often
# 85                                                      Never
# ...                                                       ...
# 61753                                 Less than once per year
# 61787                                 Less than once per year
# 61922                                 Less than once per year
# 62177                                 Less than once per year
# 62999                                                   Never
# 63462                              Once a month or more often
# 64998                                 Less than once per year
# 65265                              Once a month or more often
# 65296                                 Less than once per year
# 66751       Less than once a month but more than once per ...
# 66972                              Once a month or more often
# 67206                              Once a month or more often
# 68208                                 Less than once per year
# 68525                                 Less than once per year
# 69366                                 Less than once per year
# 69741                              Once a month or more often
# 70630       Less than once a month but more than once per ...
# 70746                                                   Never
# 70985                                                   Never
# 71160       Less than once a month but more than once per ...
# 71874                                                   Never
# 72325                              Once a month or more often
# 72492                              Once a month or more often
# 75496                                 Less than once per year
# 75974                              Once a month or more often
# 77968                                 Less than once per year
# 78292                              Once a month or more often
# 78741                                                   Never
# 79795       Less than once a month but more than once per ...
# 79798       Less than once a month but more than once per ...
# 81934       Less than once a month but more than once per ...
# 81994                                                   Never
# 82007                                 Less than once per year
# 82789                              Once a month or more often
# 83397                                 Less than once per year
# 83709                              Once a month or more often
# 84299                                                   Never
# 84539       Less than once a month but more than once per ...
# 85738                                                   Never
# 86566       Less than once a month but more than once per ...
# 87739                                 Less than once per year
# 88212                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# 8           OSS is, on average, of HIGHER quality than pro...
# 9           The quality of OSS and closed source software ...
# 10          OSS is, on average, of HIGHER quality than pro...
# 12          OSS is, on average, of HIGHER quality than pro...
# 18          The quality of OSS and closed source software ...
# 20          OSS is, on average, of HIGHER quality than pro...
# 21          OSS is, on average, of HIGHER quality than pro...
# 22          OSS is, on average, of HIGHER quality than pro...
# 23          The quality of OSS and closed source software ...
# 26          The quality of OSS and closed source software ...
# 27          OSS is, on average, of HIGHER quality than pro...
# 31                                                        NaN
# 32          The quality of OSS and closed source software ...
# 33          OSS is, on average, of HIGHER quality than pro...
# 36          The quality of OSS and closed source software ...
# 37          OSS is, on average, of LOWER quality than prop...
# 45          The quality of OSS and closed source software ...
# 46          OSS is, on average, of HIGHER quality than pro...
# 49          The quality of OSS and closed source software ...
# 50          OSS is, on average, of LOWER quality than prop...
# 51          OSS is, on average, of HIGHER quality than pro...
# 52          OSS is, on average, of HIGHER quality than pro...
# 54          OSS is, on average, of LOWER quality than prop...
# 55          The quality of OSS and closed source software ...
# 57          OSS is, on average, of HIGHER quality than pro...
# 60          OSS is, on average, of HIGHER quality than pro...
# 61          OSS is, on average, of LOWER quality than prop...
# 62          OSS is, on average, of LOWER quality than prop...
# 63          The quality of OSS and closed source software ...
# 67          OSS is, on average, of HIGHER quality than pro...
# 68          OSS is, on average, of LOWER quality than prop...
# 71          The quality of OSS and closed source software ...
# 74          OSS is, on average, of LOWER quality than prop...
# 78          The quality of OSS and closed source software ...
# 80          OSS is, on average, of HIGHER quality than pro...
# 81          The quality of OSS and closed source software ...
# 82          OSS is, on average, of HIGHER quality than pro...
# 85          OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 61753       The quality of OSS and closed source software ...
# 61787       OSS is, on average, of HIGHER quality than pro...
# 61922       The quality of OSS and closed source software ...
# 62177       OSS is, on average, of LOWER quality than prop...
# 62999                                                     NaN
# 63462       OSS is, on average, of HIGHER quality than pro...
# 64998       OSS is, on average, of HIGHER quality than pro...
# 65265       OSS is, on average, of HIGHER quality than pro...
# 65296       OSS is, on average, of HIGHER quality than pro...
# 66751       OSS is, on average, of HIGHER quality than pro...
# 66972       OSS is, on average, of HIGHER quality than pro...
# 67206       The quality of OSS and closed source software ...
# 68208       The quality of OSS and closed source software ...
# 68525                                                     NaN
# 69366       OSS is, on average, of LOWER quality than prop...
# 69741       OSS is, on average, of HIGHER quality than pro...
# 70630       OSS is, on average, of HIGHER quality than pro...
# 70746       OSS is, on average, of HIGHER quality than pro...
# 70985       The quality of OSS and closed source software ...
# 71160       The quality of OSS and closed source software ...
# 71874       OSS is, on average, of HIGHER quality than pro...
# 72325       OSS is, on average, of HIGHER quality than pro...
# 72492       The quality of OSS and closed source software ...
# 75496       The quality of OSS and closed source software ...
# 75974       OSS is, on average, of HIGHER quality than pro...
# 77968       The quality of OSS and closed source software ...
# 78292       OSS is, on average, of HIGHER quality than pro...
# 78741       OSS is, on average, of HIGHER quality than pro...
# 79795       OSS is, on average, of HIGHER quality than pro...
# 79798       OSS is, on average, of HIGHER quality than pro...
# 81934       OSS is, on average, of HIGHER quality than pro...
# 81994       The quality of OSS and closed source software ...
# 82007       The quality of OSS and closed source software ...
# 82789       The quality of OSS and closed source software ...
# 83397                                                     NaN
# 83709       The quality of OSS and closed source software ...
# 84299       The quality of OSS and closed source software ...
# 84539       The quality of OSS and closed source software ...
# 85738       The quality of OSS and closed source software ...
# 86566       OSS is, on average, of HIGHER quality than pro...
# 87739       OSS is, on average, of HIGHER quality than pro...
# 88212       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment  \
# Respondent
# 1                      Not employed, and not looking for work
# 2                          Not employed, but looking for work
# 4                                          Employed full-time
# 5                                          Employed full-time
# 8                          Not employed, but looking for work
# 9                                          Employed full-time
# 10                                         Employed full-time
# 12                                         Employed part-time
# 18                                         Employed full-time
# 20                                         Employed full-time
# 21                                                        NaN
# 22                                         Employed full-time
# 23                                         Employed full-time
# 26                                         Employed full-time
# 27                         Not employed, but looking for work
# 31                     Not employed, and not looking for work
# 32                                         Employed full-time
# 33                                         Employed full-time
# 36                                         Employed full-time
# 37                                         Employed part-time
# 45                                         Employed full-time
# 46          Independent contractor, freelancer, or self-em...
# 49                                         Employed full-time
# 50                                         Employed full-time
# 51                                         Employed part-time
# 52                                         Employed full-time
# 54                                         Employed full-time
# 55          Independent contractor, freelancer, or self-em...
# 57                                         Employed full-time
# 60                                         Employed full-time
# 61                                         Employed full-time
# 62                                         Employed full-time
# 63                                         Employed full-time
# 67                                         Employed full-time
# 68                                         Employed full-time
# 71                                         Employed full-time
# 74                                         Employed full-time
# 78                                         Employed full-time
# 80                                         Employed full-time
# 81                                         Employed full-time
# 82                                         Employed full-time
# 85          Independent contractor, freelancer, or self-em...
# ...                                                       ...
# 61753                  Not employed, and not looking for work
# 61787       Independent contractor, freelancer, or self-em...
# 61922                      Not employed, but looking for work
# 62177                                      Employed full-time
# 62999       Independent contractor, freelancer, or self-em...
# 63462                                                     NaN
# 64998                      Not employed, but looking for work
# 65265                                      Employed full-time
# 65296       Independent contractor, freelancer, or self-em...
# 66751                      Not employed, but looking for work
# 66972                                      Employed full-time
# 67206                  Not employed, and not looking for work
# 68208                                                     NaN
# 68525                      Not employed, but looking for work
# 69366                                      Employed full-time
# 69741                  Not employed, and not looking for work
# 70630                                      Employed full-time
# 70746                      Not employed, but looking for work
# 70985                                      Employed full-time
# 71160       Independent contractor, freelancer, or self-em...
# 71874       Independent contractor, freelancer, or self-em...
# 72325       Independent contractor, freelancer, or self-em...
# 72492                      Not employed, but looking for work
# 75496                                      Employed full-time
# 75974                                      Employed full-time
# 77968       Independent contractor, freelancer, or self-em...
# 78292       Independent contractor, freelancer, or self-em...
# 78741                                                     NaN
# 79795                                      Employed full-time
# 79798                                      Employed part-time
# 81934                  Not employed, and not looking for work
# 81994                                      Employed part-time
# 82007                                                     NaN
# 82789                                                     NaN
# 83397                      Not employed, but looking for work
# 83709       Independent contractor, freelancer, or self-em...
# 84299                                      Employed full-time
# 84539                                      Employed full-time
# 85738                  Not employed, and not looking for work
# 86566                                                 Retired
# 87739                                      Employed part-time
# 88212                                      Employed full-time
#
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 4                    United States              No
# 5                          Ukraine              No
# 8                            India             NaN
# 9                      New Zealand              No
# 10                           India              No
# 12                          Canada  Yes, full-time
# 18              Russian Federation              No
# 20                       Lithuania              No
# 21                          Canada             NaN
# 22                   United States              No
# 23                   United States              No
# 26                   United States              No
# 27                        Colombia  Yes, part-time
# 31                          Canada              No
# 32                   United States              No
# 33                       Argentina  Yes, full-time
# 36                         Germany  Yes, full-time
# 37                          Canada  Yes, full-time
# 45                   United States              No
# 46                   United States              No
# 49                          Serbia  Yes, full-time
# 50                           India              No
# 51                   United States  Yes, full-time
# 52                          Poland              No
# 54                          Sweden              No
# 55                       Sri Lanka  Yes, full-time
# 57                          France              No
# 60                   United States              No
# 61                   United States              No
# 62                     Netherlands  Yes, full-time
# 63                           Italy              No
# 67                       Australia              No
# 68                           India              No
# 71                     Philippines              No
# 74                         Ireland              No
# 78                           India  Yes, full-time
# 80                  United Kingdom              No
# 81                          Poland              No
# 82                  United Kingdom              No
# 85                         Germany              No
# ...                            ...             ...
# 61753                       France              No
# 61787                       Israel              No
# 61922                      Belgium              No
# 62177                       Poland             NaN
# 62999           Russian Federation              No
# 63462                       Jordan             NaN
# 64998                       Sweden              No
# 65265                       Brazil              No
# 65296                United States              No
# 66751                       Canada              No
# 66972                        Chile              No
# 67206                United States              No
# 68208                United States              No
# 68525                        Spain              No
# 69366                      Ukraine  Yes, part-time
# 69741                       Canada              No
# 70630                 South Africa              No
# 70746                     Bulgaria  Yes, part-time
# 70985                      Albania             NaN
# 71160                      Austria  Yes, full-time
# 71874                        India              No
# 72325                United States              No
# 72492                       Brazil              No
# 75496                       Canada              No
# 75974                      Germany              No
# 77968           Russian Federation              No
# 78292                United States              No
# 78741               United Kingdom  Yes, full-time
# 79795                        India              No
# 79798               United Kingdom  Yes, full-time
# 81934                         Oman              No
# 81994                       Poland  Yes, full-time
# 82007                       Canada             NaN
# 82789               United Kingdom              No
# 83397                United States              No
# 83709                    Argentina  Yes, part-time
# 84299                        India  Yes, full-time
# 84539               United Kingdom  Yes, full-time
# 85738                       Brazil  Yes, full-time
# 86566                  Switzerland              No
# 87739               Czech Republic  Yes, full-time
# 88212                        Spain              No
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 4                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 12          Some college/university study without earning ...
# 18                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 20                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 21                                                        NaN
# 22          Some college/university study without earning ...
# 23                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 26          Some college/university study without earning ...
# 27          Some college/university study without earning ...
# 31                                  Primary/elementary school
# 32                                           Associate degree
# 33                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 36          Secondary school (e.g. American high school, G...
# 37                                           Associate degree
# 45                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 46                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 49          Some college/university study without earning ...
# 50                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 51          Some college/university study without earning ...
# 52          Some college/university study without earning ...
# 54                                                        NaN
# 55                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 57                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 60          Secondary school (e.g. American high school, G...
# 61          Some college/university study without earning ...
# 62                                           Associate degree
# 63                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 67                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 68                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 71                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 74                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 78                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 80                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 81                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 82                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 85                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                       ...
# 61753       Some college/university study without earning ...
# 61787                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 61922       Some college/university study without earning ...
# 62177       Secondary school (e.g. American high school, G...
# 62999                               Primary/elementary school
# 63462                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 64998       Secondary school (e.g. American high school, G...
# 65265               Other doctoral degree (Ph.D, Ed.D., etc.)
# 65296             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 66751                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 66972                      Professional degree (JD, MD, etc.)
# 67206       Secondary school (e.g. American high school, G...
# 68208       Some college/university study without earning ...
# 68525                               Primary/elementary school
# 69366             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 69741                               Primary/elementary school
# 70630                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 70746                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 70985                                                     NaN
# 71160       Secondary school (e.g. American high school, G...
# 71874                                                     NaN
# 72325       Secondary school (e.g. American high school, G...
# 72492       Some college/university study without earning ...
# 75496             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 75974                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 77968             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 78292               Other doctoral degree (Ph.D, Ed.D., etc.)
# 78741                                                     NaN
# 79795                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 79798                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 81934             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 81994                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 82007                               Primary/elementary school
# 82789       Secondary school (e.g. American high school, G...
# 83397                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83709                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84539                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 85738       Secondary school (e.g. American high school, G...
# 86566       Some college/university study without earning ...
# 87739             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88212       Secondary school (e.g. American high school, G...
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10                                                        NaN
# 12                                  Mathematics or statistics
# 18          Computer science, computer engineering, or sof...
# 20          Information systems, information technology, o...
# 21                                                        NaN
# 22                                                        NaN
# 23          Information systems, information technology, o...
# 26          Computer science, computer engineering, or sof...
# 27          Information systems, information technology, o...
# 31                                                        NaN
# 32          Information systems, information technology, o...
# 33          A natural science (ex. biology, chemistry, phy...
# 36                                                        NaN
# 37          A social science (ex. anthropology, psychology...
# 45          Another engineering discipline (ex. civil, ele...
# 46          Another engineering discipline (ex. civil, ele...
# 49          Computer science, computer engineering, or sof...
# 50          Another engineering discipline (ex. civil, ele...
# 51          Computer science, computer engineering, or sof...
# 52          Computer science, computer engineering, or sof...
# 54          Computer science, computer engineering, or sof...
# 55          Computer science, computer engineering, or sof...
# 57          A business discipline (ex. accounting, finance...
# 60                                                        NaN
# 61          Computer science, computer engineering, or sof...
# 62          Computer science, computer engineering, or sof...
# 63          A natural science (ex. biology, chemistry, phy...
# 67          Information systems, information technology, o...
# 68                              Web development or web design
# 71          Computer science, computer engineering, or sof...
# 74          Computer science, computer engineering, or sof...
# 78          Computer science, computer engineering, or sof...
# 80                                  Mathematics or statistics
# 81          Computer science, computer engineering, or sof...
# 82          Computer science, computer engineering, or sof...
# 85          Computer science, computer engineering, or sof...
# ...                                                       ...
# 61753                               Mathematics or statistics
# 61787       Computer science, computer engineering, or sof...
# 61922       Computer science, computer engineering, or sof...
# 62177                                                     NaN
# 62999                                                     NaN
# 63462                                                     NaN
# 64998                                                     NaN
# 65265       Computer science, computer engineering, or sof...
# 65296       A social science (ex. anthropology, psychology...
# 66751                                                     NaN
# 66972       Computer science, computer engineering, or sof...
# 67206                                                     NaN
# 68208                                I never declared a major
# 68525                                                     NaN
# 69366       A humanities discipline (ex. literature, histo...
# 69741                                                     NaN
# 70630       Computer science, computer engineering, or sof...
# 70746                               Mathematics or statistics
# 70985                                                     NaN
# 71160                                                     NaN
# 71874                                                     NaN
# 72325                                                     NaN
# 72492                                I never declared a major
# 75496       Computer science, computer engineering, or sof...
# 75974       Another engineering discipline (ex. civil, ele...
# 77968       Information systems, information technology, o...
# 78292       A health science (ex. nursing, pharmacy, radio...
# 78741       Fine arts or performing arts (ex. graphic desi...
# 79795       Computer science, computer engineering, or sof...
# 79798       Computer science, computer engineering, or sof...
# 81934       Computer science, computer engineering, or sof...
# 81994       Computer science, computer engineering, or sof...
# 82007                                                     NaN
# 82789                                                     NaN
# 83397       Computer science, computer engineering, or sof...
# 83709       Computer science, computer engineering, or sof...
# 84299                           Web development or web design
# 84539       Computer science, computer engineering, or sof...
# 85738                                                     NaN
# 86566       A humanities discipline (ex. literature, histo...
# 87739       Computer science, computer engineering, or sof...
# 88212                                                     NaN
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
# 8           Taught yourself a new language, framework, or ...
# 9           Taken an online course in programming or softw...
# 10                                                        NaN
# 12          Taken an online course in programming or softw...
# 18          Taken an online course in programming or softw...
# 20          Taken an online course in programming or softw...
# 21          Taught yourself a new language, framework, or ...
# 22          Taken an online course in programming or softw...
# 23          Taken an online course in programming or softw...
# 26          Taught yourself a new language, framework, or ...
# 27          Taken an online course in programming or softw...
# 31                                                        NaN
# 32          Completed an industry certification program (e...
# 33          Taken an online course in programming or softw...
# 36          Taken an online course in programming or softw...
# 37          Taken a part-time in-person course in programm...
# 45          Received on-the-job training in software devel...
# 46          Taken an online course in programming or softw...
# 49          Taught yourself a new language, framework, or ...
# 50          Received on-the-job training in software devel...
# 51          Taken an online course in programming or softw...
# 52          Taught yourself a new language, framework, or ...
# 54          Taken an online course in programming or softw...
# 55          Received on-the-job training in software devel...
# 57          Taken an online course in programming or softw...
# 60          Taught yourself a new language, framework, or ...
# 61          Taken an online course in programming or softw...
# 62          Taken an online course in programming or softw...
# 63          Received on-the-job training in software devel...
# 67          Taken an online course in programming or softw...
# 68          Taken an online course in programming or softw...
# 71          Received on-the-job training in software devel...
# 74          Taken an online course in programming or softw...
# 78          Received on-the-job training in software devel...
# 80          Taken an online course in programming or softw...
# 81          Taken an online course in programming or softw...
# 82          Taken an online course in programming or softw...
# 85          Taken an online course in programming or softw...
# ...                                                       ...
# 61753       Taken an online course in programming or softw...
# 61787       Taken an online course in programming or softw...
# 61922       Taken an online course in programming or softw...
# 62177                                                     NaN
# 62999       Taught yourself a new language, framework, or ...
# 63462                                                     NaN
# 64998       Taken an online course in programming or softw...
# 65265       Taught yourself a new language, framework, or ...
# 65296       Taken an online course in programming or softw...
# 66751       Taught yourself a new language, framework, or ...
# 66972       Taken an online course in programming or softw...
# 67206       Taken an online course in programming or softw...
# 68208       Completed an industry certification program (e...
# 68525       Taken an online course in programming or softw...
# 69366       Taken an online course in programming or softw...
# 69741       Taught yourself a new language, framework, or ...
# 70630       Taught yourself a new language, framework, or ...
# 70746       Taken an online course in programming or softw...
# 70985                                                     NaN
# 71160       Completed an industry certification program (e...
# 71874                                                     NaN
# 72325       Taken an online course in programming or softw...
# 72492       Taught yourself a new language, framework, or ...
# 75496       Taken an online course in programming or softw...
# 75974       Taught yourself a new language, framework, or ...
# 77968       Taken a part-time in-person course in programm...
# 78292       Completed an industry certification program (e...
# 78741       Taken an online course in programming or softw...
# 79795       Taken an online course in programming or softw...
# 79798       Taught yourself a new language, framework, or ...
# 81934       Taken an online course in programming or softw...
# 81994       Taken an online course in programming or softw...
# 82007                                                     NaN
# 82789       Taken an online course in programming or softw...
# 83397       Taken an online course in programming or softw...
# 83709       Taken an online course in programming or softw...
# 84299       Taken an online course in programming or softw...
# 84539       Taken an online course in programming or softw...
# 85738       Taught yourself a new language, framework, or ...
# 86566       Taken a part-time in-person course in programm...
# 87739       Taught yourself a new language, framework, or ...
# 88212       Taught yourself a new language, framework, or ...
#
#                                                       OrgSize  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 4                                        100 to 499 employees
# 5                                    10,000 or more employees
# 8                                                         NaN
# 9                                          10 to 19 employees
# 10                                   10,000 or more employees
# 12                                                        NaN
# 18                                   1,000 to 4,999 employees
# 20                                   1,000 to 4,999 employees
# 21                                                        NaN
# 22                                   10,000 or more employees
# 23                                   10,000 or more employees
# 26                                   10,000 or more employees
# 27                                                        NaN
# 31                                                        NaN
# 32                                       100 to 499 employees
# 33                                   10,000 or more employees
# 36                                   1,000 to 4,999 employees
# 37                                       100 to 499 employees
# 45                                   1,000 to 4,999 employees
# 46          Just me - I am a freelancer, sole proprietor, ...
# 49                                         20 to 99 employees
# 50                                   10,000 or more employees
# 51                                                        NaN
# 52                                         20 to 99 employees
# 54                                         20 to 99 employees
# 55                                                        NaN
# 57                                   10,000 or more employees
# 60                                       100 to 499 employees
# 61                                         20 to 99 employees
# 62                                   10,000 or more employees
# 63                                         20 to 99 employees
# 67                                   1,000 to 4,999 employees
# 68                                         10 to 19 employees
# 71                                         20 to 99 employees
# 74                                   10,000 or more employees
# 78                                              2-9 employees
# 80                                       500 to 999 employees
# 81                                   10,000 or more employees
# 82                                   10,000 or more employees
# 85          Just me - I am a freelancer, sole proprietor, ...
# ...                                                       ...
# ...
# 84539                                                   Woman   Yes
# 85738                                                     Man    No
# 86566                                                     Man    No
# 87739                                                     NaN    No
# 88212                                                     Man    No
#
#                           Sexuality  \
# Respondent
# 1           Straight / Heterosexual
# 2           Straight / Heterosexual
# 4           Straight / Heterosexual
# 5           Straight / Heterosexual
# 8           Straight / Heterosexual
# 9                          Bisexual
# 10                              NaN
# 12          Straight / Heterosexual
# 18          Straight / Heterosexual
# 20          Straight / Heterosexual
# 21                              NaN
# 22          Straight / Heterosexual
# 23          Straight / Heterosexual
# 26                   Gay or Lesbian
# 27          Straight / Heterosexual
# 31                              NaN
# 32          Straight / Heterosexual
# 33          Straight / Heterosexual
# 36          Straight / Heterosexual
# 37                              NaN
# 45          Straight / Heterosexual
# 46          Straight / Heterosexual
# 49          Straight / Heterosexual
# 50                              NaN
# 51          Straight / Heterosexual
# 52                              NaN
# 54          Straight / Heterosexual
# 55          Straight / Heterosexual
# 57          Straight / Heterosexual
# 60                         Bisexual
# 61          Straight / Heterosexual
# 62          Straight / Heterosexual
# 63          Straight / Heterosexual
# 67          Straight / Heterosexual
# 68          Straight / Heterosexual
# 71          Straight / Heterosexual
# 74          Straight / Heterosexual
# 78                              NaN
# 80          Straight / Heterosexual
# 81                              NaN
# 82                              NaN
# 85          Straight / Heterosexual
# ...                             ...
# 61753                           NaN
# 61787       Straight / Heterosexual
# 61922       Straight / Heterosexual
# 62177                           NaN
# 62999       Straight / Heterosexual
# 63462                           NaN
# 64998       Straight / Heterosexual
# 65265       Straight / Heterosexual
# 65296       Straight / Heterosexual
# 66751                           NaN
# 66972                           NaN
# 67206       Straight / Heterosexual
# 68208       Straight / Heterosexual
# 68525       Straight / Heterosexual
# 69366       Straight / Heterosexual
# 69741       Straight / Heterosexual
# 70630       Straight / Heterosexual
# 70746       Straight / Heterosexual
# 70985                           NaN
# 71160       Straight / Heterosexual
# 71874                           NaN
# 72325                           NaN
# 72492       Bisexual;Gay or Lesbian
# 75496       Straight / Heterosexual
# 75974                           NaN
# 77968       Straight / Heterosexual
# 78292       Straight / Heterosexual
# 78741                           NaN
# 79795       Straight / Heterosexual
# 79798       Straight / Heterosexual
# 81934       Straight / Heterosexual
# 81994                           NaN
# 82007       Straight / Heterosexual
# 82789       Straight / Heterosexual
# 83397                      Bisexual
# 83709                           NaN
# 84299                           NaN
# 84539                      Bisexual
# 85738       Straight / Heterosexual
# 86566                           NaN
# 87739       Straight / Heterosexual
# 88212       Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 1                                                         NaN         No
# 2                                                         NaN         No
# 4                                White or of European descent         No
# 5                    White or of European descent;Multiracial         No
# 8                                                         NaN        NaN
# 9                                White or of European descent         No
# 10                                                        NaN        Yes
# 12                                Black or of African descent         No
# 18                               White or of European descent        Yes
# 20                               White or of European descent        Yes
# 21                                                        NaN         No
# 22                               White or of European descent        Yes
# 23                                Black or of African descent         No
# 26                                                        NaN         No
# 27                                  Hispanic or Latino/Latina         No
# 31                                                 East Asian         No
# 32                               White or of European descent         No
# 33                                  Hispanic or Latino/Latina         No
# 36                               White or of European descent         No
# 37                               White or of European descent         No
# 45                               White or of European descent         No
# 46                               White or of European descent         No
# 49                               White or of European descent        Yes
# 50                                                South Asian         No
# 51                                                South Asian         No
# 52                                                        NaN         No
# 54                               White or of European descent         No
# 55                                                South Asian        Yes
# 57                                                        NaN         No
# 60                               White or of European descent         No
# 61                               White or of European descent         No
# 62                               White or of European descent         No
# 63                                                        NaN         No
# 67                                                Multiracial         No
# 68                                                South Asian         No
# 71                                     East Asian;South Asian         No
# 74                               White or of European descent         No
# 78                                                        NaN        Yes
# 80                                                   Biracial         No
# 81                               White or of European descent         No
# 82                                                        NaN         No
# 85                               White or of European descent        NaN
# ...                                                       ...        ...
# 61753       Black or of African descent;East Asian;Middle ...         No
# 61787                            White or of European descent         No
# 61922                            White or of European descent         No
# 62177                            White or of European descent        NaN
# 62999                                                     NaN         No
# 63462                                          Middle Eastern        NaN
# 64998                            White or of European descent         No
# 65265                                                     NaN        Yes
# 65296                            White or of European descent        Yes
# 66751                            White or of European descent         No
# 66972                               Hispanic or Latino/Latina        Yes
# 67206                                             South Asian         No
# 68208                            White or of European descent        Yes
# 68525                            White or of European descent         No
# 69366                            White or of European descent        Yes
# 69741                            White or of European descent         No
# 70630                            White or of European descent         No
# 70746                            White or of European descent        Yes
# 70985                                                     NaN        NaN
# 71160                            White or of European descent         No
# 71874                                                     NaN        Yes
# 72325                            White or of European descent         No
# 72492                               Hispanic or Latino/Latina         No
# 75496                                             South Asian        NaN
# 75974                                          Middle Eastern        Yes
# 77968                            White or of European descent         No
# 78292                            White or of European descent        Yes
# 78741       Black or of African descent;East Asian;Hispani...        Yes
# 79795                                                     NaN         No
# 79798                            White or of European descent         No
# 81934                            White or of European descent         No
# 81994                            White or of European descent         No
# 82007                            White or of European descent         No
# 82789                   White or of European descent;Biracial         No
# 83397                            White or of European descent         No
# 83709                                                     NaN         No
# 84299                                                     NaN        NaN
# 84539                            White or of European descent         No
# 85738       Hispanic or Latino/Latina;White or of European...         No
# 86566                            White or of European descent         No
# 87739                            White or of European descent         No
# 88212                            White or of European descent         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 8           Appropriate in length  Neither easy nor difficult
# 9           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 12          Appropriate in length                        Easy
# 18          Appropriate in length  Neither easy nor difficult
# 20          Appropriate in length                        Easy
# 21          Appropriate in length                        Easy
# 22          Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 26          Appropriate in length                        Easy
# 27          Appropriate in length  Neither easy nor difficult
# 31                       Too long  Neither easy nor difficult
# 32          Appropriate in length  Neither easy nor difficult
# 33          Appropriate in length  Neither easy nor difficult
# 36                       Too long  Neither easy nor difficult
# 37          Appropriate in length  Neither easy nor difficult
# 45          Appropriate in length  Neither easy nor difficult
# 46                       Too long  Neither easy nor difficult
# 49                       Too long                        Easy
# 50                       Too long                        Easy
# 51                       Too long                        Easy
# 52          Appropriate in length  Neither easy nor difficult
# 54          Appropriate in length                        Easy
# 55                       Too long  Neither easy nor difficult
# 57          Appropriate in length                        Easy
# 60                            NaN                         NaN
# 61          Appropriate in length                        Easy
# 62          Appropriate in length                        Easy
# 63                       Too long  Neither easy nor difficult
# 67          Appropriate in length                        Easy
# 68          Appropriate in length                        Easy
# 71          Appropriate in length                        Easy
# 74          Appropriate in length  Neither easy nor difficult
# 78          Appropriate in length                        Easy
# 80          Appropriate in length  Neither easy nor difficult
# 81          Appropriate in length                        Easy
# 82                       Too long  Neither easy nor difficult
# 85          Appropriate in length                        Easy
# ...                           ...                         ...
# 61753       Appropriate in length  Neither easy nor difficult
# 61787       Appropriate in length                        Easy
# 61922       Appropriate in length  Neither easy nor difficult
# 62177       Appropriate in length                   Difficult
# 62999                    Too long                        Easy
# 63462       Appropriate in length  Neither easy nor difficult
# 64998       Appropriate in length                        Easy
# 65265       Appropriate in length  Neither easy nor difficult
# 65296                    Too long  Neither easy nor difficult
# 66751       Appropriate in length  Neither easy nor difficult
# 66972                    Too long  Neither easy nor difficult
# 67206                    Too long                        Easy
# 68208                         NaN                         NaN
# 68525                   Too short                        Easy
# 69366                    Too long                        Easy
# 69741       Appropriate in length                        Easy
# 70630                    Too long  Neither easy nor difficult
# 70746       Appropriate in length                        Easy
# 70985                         NaN                         NaN
# 71160       Appropriate in length  Neither easy nor difficult
# 71874                    Too long                        Easy
# 72325       Appropriate in length                        Easy
# 72492                   Too short                        Easy
# 75496                    Too long                        Easy
# 75974       Appropriate in length                        Easy
# 77968       Appropriate in length                        Easy
# 78292                    Too long  Neither easy nor difficult
# 78741       Appropriate in length                        Easy
# 79795                    Too long                   Difficult
# 79798       Appropriate in length                        Easy
# 81934       Appropriate in length                        Easy
# 81994                    Too long                        Easy
# 82007       Appropriate in length  Neither easy nor difficult
# 82789       Appropriate in length                        Easy
# 83397       Appropriate in length                        Easy
# 83709       Appropriate in length  Neither easy nor difficult
# 84299                         NaN                         NaN
# 84539       Appropriate in length                        Easy
# 85738                   Too short                        Easy
# 86566       Appropriate in length                        Easy
# 87739       Appropriate in length                        Easy
# 88212       Appropriate in length                        Easy
#
# [36443 rows x 84 columns]

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1              NaN
# 2              NaN
# 3           8820.0
# 4          61000.0
# 5              NaN
# 6         366420.0
# 7              NaN
# 8              NaN
# 9          95179.0
# 10         13293.0
# 11             NaN
# 12             NaN
# 13         90000.0
# 14         57060.0
# 15             NaN
# 16        455352.0
# 17         65277.0
# 18         21996.0
# 19         31140.0
# 20         41244.0
# 21             NaN
# 22        103000.0
# 23         69000.0
# 24         26388.0
# 25          6300.0
# 26        114000.0
# 27             NaN
# 28             NaN
# 29        100000.0
# 30         90417.0
# 31             NaN
# 32       1100000.0
# 33          8400.0
# 34             NaN
# 35         80000.0
# 36         20628.0
# 37             NaN
# 38         51312.0
# 39        156000.0
# 40             NaN
# 41             NaN
# 42             NaN
#            ...
# 82789          NaN
# 82805          NaN
# 83000          NaN
# 83397          NaN
# 83511          NaN
# 83612          NaN
# 83648          NaN
# 83709          NaN
# 83777          NaN
# 83786          NaN
# 83800          NaN
# 83862          NaN
# 84299          NaN
# 84539          NaN
# 85182          NaN
# 85208          NaN
# 85396          NaN
# 85538          NaN
# 85642          NaN
# 85738          NaN
# 85744          NaN
# 85955          NaN
# 85961          NaN
# 86012          NaN
# 86566          NaN
# 86638          NaN
# 86806          NaN
# 86980          NaN
# 86999          NaN
# 87352          NaN
# 87386          NaN
# 87739          NaN
# 88062          NaN
# 88076          NaN
# 88182          NaN
# 88212          NaN
# 88282          NaN
# 88377          NaN
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863          NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
# 6        Yes
# 7         No
# 8        Yes
# 9        Yes
# 10       Yes
# 11       Yes
# 12        No
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18       Yes
# 19       Yes
# 20        No
# 21       Yes
# 22       Yes
# 23       Yes
# 24       Yes
# 25        No
# 26       Yes
# 27       Yes
# 28       Yes
# 29       Yes
# 30        No
# 31        No
# 32        No
# 33        No
# 34       Yes
# 35        No
# 36       Yes
# 37       Yes
# 38       Yes
# 39       Yes
# 40       Yes
# 41       Yes
# 42       Yes
#         ...
# 82789    Yes
# 82805    Yes
# 83000     No
# 83397    Yes
# 83511     No
# 83612    Yes
# 83648     No
# 83709    Yes
# 83777     No
# 83786     No
# 83800     No
# 83862    Yes
# 84299    Yes
# 84539    Yes
# 85182     No
# 85208     No
# 85396     No
# 85538     No
# 85642     No
# 85738    Yes
# 85744     No
# 85955    Yes
# 85961    Yes
# 86012    Yes
# 86566    Yes
# 86638    Yes
# 86806    Yes
# 86980     No
# 86999     No
# 87352    Yes
# 87386    Yes
# 87739    Yes
# 88062     No
# 88076     No
# 88182    Yes
# 88212     No
# 88282    Yes
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': False})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
# 6         True
# 7        False
# 8         True
# 9         True
# 10        True
# 11        True
# 12       False
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20       False
# 21        True
# 22        True
# 23        True
# 24        True
# 25       False
# 26        True
# 27        True
# 28        True
# 29        True
# 30       False
# 31       False
# 32       False
# 33       False
# 34        True
# 35       False
# 36        True
# 37        True
# 38        True
# 39        True
# 40        True
# 41        True
# 42        True
#          ...
# 82789     True
# 82805     True
# 83000    False
# 83397     True
# 83511    False
# 83612     True
# 83648    False
# 83709     True
# 83777    False
# 83786    False
# 83800    False
# 83862     True
# 84299     True
# 84539     True
# 85182    False
# 85208    False
# 85396    False
# 85538    False
# 85642    False
# 85738     True
# 85744    False
# 85955     True
# 85961     True
# 86012     True
# 86566     True
# 86638     True
# 86806     True
# 86980    False
# 86999    False
# 87352     True
# 87386     True
# 87739     True
# 88062    False
# 88076    False
# 88182     True
# 88212    False
# 88282     True
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})
df
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      True
# 2                      I am a student who is learning to code     False
# 3           I am not primarily a developer, but I write co...      True
# 4                              I am a developer by profession     False
# 5                              I am a developer by profession      True
# 6           I am not primarily a developer, but I write co...      True
# 7                              I am a developer by profession     False
# 8                                 I code primarily as a hobby      True
# 9                              I am a developer by profession      True
# 10                             I am a developer by profession      True
# 11                                I code primarily as a hobby      True
# 12                     I am a student who is learning to code     False
# 13                             I am a developer by profession      True
# 14                             I am a developer by profession      True
# 15                     I am a student who is learning to code      True
# 16                             I am a developer by profession      True
# 17                             I am a developer by profession      True
# 18          I am not primarily a developer, but I write co...      True
# 19                             I am a developer by profession      True
# 20          I am not primarily a developer, but I write co...     False
# 21                                I code primarily as a hobby      True
# 22                             I am a developer by profession      True
# 23                             I am a developer by profession      True
# 24                             I am a developer by profession      True
# 25                             I am a developer by profession     False
# 26                             I am a developer by profession      True
# 27          I used to be a developer by profession, but no...      True
# 28                             I am a developer by profession      True
# 29                             I am a developer by profession      True
# 30                             I am a developer by profession     False
# 31                     I am a student who is learning to code     False
# 32                             I am a developer by profession     False
# 33                             I am a developer by profession     False
# 34                     I am a student who is learning to code      True
# 35                             I am a developer by profession     False
# 36                             I am a developer by profession      True
# 37                                I code primarily as a hobby      True
# 38                             I am a developer by profession      True
# 39                             I am a developer by profession      True
# 40                     I am a student who is learning to code      True
# 41                             I am a developer by profession      True
# 42                             I am a developer by profession      True
# ...                                                       ...       ...
# 82789                                                     NaN      True
# 82805                                                     NaN      True
# 83000                                                     NaN     False
# 83397                                                     NaN      True
# 83511                                                     NaN     False
# 83612                                                     NaN      True
# 83648                                                     NaN     False
# 83709                                                     NaN      True
# 83777                                                     NaN     False
# 83786                                                     NaN     False
# 83800                                                     NaN     False
# 83862                                                     NaN      True
# 84299                                                     NaN      True
# 84539                                                     NaN      True
# 85182                                                     NaN     False
# 85208                                                     NaN     False
# 85396                                                     NaN     False
# 85538                                                     NaN     False
# 85642                                                     NaN     False
# 85738                                                     NaN      True
# 85744                                                     NaN     False
# 85955                                                     NaN      True
# 85961                                                     NaN      True
# 86012                                                     NaN      True
# 86566                                                     NaN      True
# 86638                                                     NaN      True
# 86806                                                     NaN      True
# 86980                                                     NaN     False
# 86999                                                     NaN     False
# 87352                                                     NaN      True
# 87386                                                     NaN      True
# 87739                                                     NaN      True
# 88062                                                     NaN     False
# 88076                                                     NaN     False
# 88182                                                     NaN      True
# 88212                                                     NaN     False
# 88282                                                     NaN      True
# 88377                                                     NaN      True
# 88601                                                     NaN     False
# 88802                                                     NaN     False
# 88816                                                     NaN     False
# 88863                                                     NaN      True
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# 3                                                       Never
# 4                                                       Never
# 5                                  Once a month or more often
# 6                                                       Never
# 7                                                       Never
# 8                                     Less than once per year
# 9                                  Once a month or more often
# 10                                 Once a month or more often
# 11                                 Once a month or more often
# 12                                                      Never
# 13          Less than once a month but more than once per ...
# 14                                    Less than once per year
# 15                                                      Never
# 16                                                      Never
# 17          Less than once a month but more than once per ...
# 18          Less than once a month but more than once per ...
# 19                                                      Never
# 20                                                      Never
# 21                                 Once a month or more often
# 22                                    Less than once per year
# 23                                    Less than once per year
# 24                                                      Never
# 25                                                      Never
# 26                                    Less than once per year
# 27                                    Less than once per year
# 28                                    Less than once per year
# 29          Less than once a month but more than once per ...
# 30          Less than once a month but more than once per ...
# 31                                                      Never
# 32                                                      Never
# 33          Less than once a month but more than once per ...
# 34                                                      Never
# 35                                                      Never
# 36          Less than once a month but more than once per ...
# 37                                    Less than once per year
# 38                                                      Never
# 39                                    Less than once per year
# 40                                                      Never
# 41                                    Less than once per year
# 42          Less than once a month but more than once per ...
# ...                                                       ...
# 82789                              Once a month or more often
# 82805       Less than once a month but more than once per ...
# 83000                                 Less than once per year
# 83397                                 Less than once per year
# 83511                                                   Never
# 83612                                                   Never
# 83648                                                   Never
# 83709                              Once a month or more often
# 83777                                                   Never
# 83786                              Once a month or more often
# 83800                                                   Never
# 83862                              Once a month or more often
# 84299                                                   Never
# 84539       Less than once a month but more than once per ...
# 85182       Less than once a month but more than once per ...
# 85208                                                   Never
# 85396       Less than once a month but more than once per ...
# 85538                                                   Never
# 85642                                 Less than once per year
# 85738                                                   Never
# 85744                                                   Never
# 85955                                 Less than once per year
# 85961                                 Less than once per year
# 86012                              Once a month or more often
# 86566       Less than once a month but more than once per ...
# 86638                                                   Never
# 86806                              Once a month or more often
# 86980                                                   Never
# 86999                                                   Never
# 87352                                 Less than once per year
# 87386       Less than once a month but more than once per ...
# 87739                                 Less than once per year
# 88062                                                   Never
# 88076                                                   Never
# 88182                              Once a month or more often
# 88212                                 Less than once per year
# 88282                              Once a month or more often
# 88377       Less than once a month but more than once per ...
# 88601                                                   Never
# 88802                                                   Never
# 88816                                                   Never
# 88863                                 Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# 6           The quality of OSS and closed source software ...
# 7           The quality of OSS and closed source software ...
# 8           OSS is, on average, of HIGHER quality than pro...
# 9           The quality of OSS and closed source software ...
# 10          OSS is, on average, of HIGHER quality than pro...
# 11          The quality of OSS and closed source software ...
# 12          OSS is, on average, of HIGHER quality than pro...
# 13          OSS is, on average, of HIGHER quality than pro...
# 14          The quality of OSS and closed source software ...
# 15          OSS is, on average, of HIGHER quality than pro...
# 16          The quality of OSS and closed source software ...
# 17          The quality of OSS and closed source software ...
# 18          The quality of OSS and closed source software ...
# 19          The quality of OSS and closed source software ...
# 20          OSS is, on average, of HIGHER quality than pro...
# 21          OSS is, on average, of HIGHER quality than pro...
# 22          OSS is, on average, of HIGHER quality than pro...
# 23          The quality of OSS and closed source software ...
# 24          OSS is, on average, of HIGHER quality than pro...
# 25          OSS is, on average, of HIGHER quality than pro...
# 26          The quality of OSS and closed source software ...
# 27          OSS is, on average, of HIGHER quality than pro...
# 28          The quality of OSS and closed source software ...
# 29          OSS is, on average, of HIGHER quality than pro...
# 30          OSS is, on average, of HIGHER quality than pro...
# 31                                                        NaN
# 32          The quality of OSS and closed source software ...
# 33          OSS is, on average, of HIGHER quality than pro...
# 34          OSS is, on average, of HIGHER quality than pro...
# 35          OSS is, on average, of HIGHER quality than pro...
# 36          The quality of OSS and closed source software ...
# 37          OSS is, on average, of LOWER quality than prop...
# 38          OSS is, on average, of LOWER quality than prop...
# 39          The quality of OSS and closed source software ...
# 40          OSS is, on average, of HIGHER quality than pro...
# 41          OSS is, on average, of HIGHER quality than pro...
# 42          OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 82789       The quality of OSS and closed source software ...
# 82805       The quality of OSS and closed source software ...
# 83000       OSS is, on average, of HIGHER quality than pro...
# 83397                                                     NaN
# 83511       OSS is, on average, of LOWER quality than prop...
# 83612       OSS is, on average, of HIGHER quality than pro...
# 83648                                                     NaN
# 83709       The quality of OSS and closed source software ...
# 83777                                                     NaN
# 83786       The quality of OSS and closed source software ...
# 83800       OSS is, on average, of LOWER quality than prop...
# 83862       OSS is, on average, of HIGHER quality than pro...
# 84299       The quality of OSS and closed source software ...
# 84539       The quality of OSS and closed source software ...
# 85182       The quality of OSS and closed source software ...
# 85208       The quality of OSS and closed source software ...
# 85396       OSS is, on average, of HIGHER quality than pro...
# 85538       OSS is, on average, of HIGHER quality than pro...
# 85642       OSS is, on average, of LOWER quality than prop...
# 85738       The quality of OSS and closed source software ...
# 85744       OSS is, on average, of LOWER quality than prop...
# 85955       OSS is, on average, of LOWER quality than prop...
# 85961       The quality of OSS and closed source software ...
# 86012       OSS is, on average, of HIGHER quality than pro...
# 86566       OSS is, on average, of HIGHER quality than pro...
# 86638       OSS is, on average, of HIGHER quality than pro...
# 86806       OSS is, on average, of HIGHER quality than pro...
# 86980       The quality of OSS and closed source software ...
# 86999       OSS is, on average, of LOWER quality than prop...
# 87352                                                     NaN
# 87386       OSS is, on average, of LOWER quality than prop...
# 87739       OSS is, on average, of HIGHER quality than pro...
# 88062       OSS is, on average, of LOWER quality than prop...
# 88076       OSS is, on average, of HIGHER quality than pro...
# 88182       OSS is, on average, of HIGHER quality than pro...
# 88212       OSS is, on average, of HIGHER quality than pro...
# 88282       The quality of OSS and closed source software ...
# 88377       The quality of OSS and closed source software ...
# 88601       The quality of OSS and closed source software ...
# 88802                                                     NaN
# 88816       OSS is, on average, of HIGHER quality than pro...
# 88863       OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment  \
# Respondent
# 1                      Not employed, and not looking for work
# 2                          Not employed, but looking for work
# 3                                          Employed full-time
# 4                                          Employed full-time
# 5                                          Employed full-time
# 6                                          Employed full-time
# 7           Independent contractor, freelancer, or self-em...
# 8                          Not employed, but looking for work
# 9                                          Employed full-time
# 10                                         Employed full-time
# 11                                                        NaN
# 12                                         Employed part-time
# 13                                         Employed full-time
# 14                                         Employed full-time
# 15                         Not employed, but looking for work
# 16                                         Employed full-time
# 17                                         Employed full-time
# 18                                         Employed full-time
# 19                                         Employed full-time
# 20                                         Employed full-time
# 21                                                        NaN
# 22                                         Employed full-time
# 23                                         Employed full-time
# 24                                         Employed full-time
# 25                                         Employed full-time
# 26                                         Employed full-time
# 27                         Not employed, but looking for work
# 28                                         Employed full-time
# 29                                         Employed full-time
# 30                                         Employed full-time
# 31                     Not employed, and not looking for work
# 32                                         Employed full-time
# 33                                         Employed full-time
# 34                         Not employed, but looking for work
# 35                                         Employed full-time
# 36                                         Employed full-time
# 37                                         Employed part-time
# 38                                         Employed full-time
# 39                                         Employed full-time
# 40          Independent contractor, freelancer, or self-em...
# 41                                         Employed part-time
# 42                                         Employed full-time
# ...                                                       ...
# 82789                                                     NaN
# 82805       Independent contractor, freelancer, or self-em...
# 83000                                      Employed full-time
# 83397                      Not employed, but looking for work
# 83511                                      Employed full-time
# 83612                                      Employed full-time
# 83648                                                     NaN
# 83709       Independent contractor, freelancer, or self-em...
# 83777                      Not employed, but looking for work
# 83786                                      Employed full-time
# 83800                                      Employed full-time
# 83862                                      Employed full-time
# 84299                                      Employed full-time
# 84539                                      Employed full-time
# 85182                                                     NaN
# 85208                      Not employed, but looking for work
# 85396       Independent contractor, freelancer, or self-em...
# 85538                  Not employed, and not looking for work
# 85642       Independent contractor, freelancer, or self-em...
# 85738                  Not employed, and not looking for work
# 85744                                                     NaN
# 85955                  Not employed, and not looking for work
# 85961                                                     NaN
# 86012                                      Employed full-time
# 86566                                                 Retired
# 86638                  Not employed, and not looking for work
# 86806                                      Employed part-time
# 86980                      Not employed, but looking for work
# 86999                  Not employed, and not looking for work
# 87352                  Not employed, and not looking for work
# 87386       Independent contractor, freelancer, or self-em...
# 87739                                      Employed part-time
# 88062                                                     NaN
# 88076                                      Employed full-time
# 88182                                      Employed part-time
# 88212                                      Employed full-time
# 88282                      Not employed, but looking for work
# 88377                  Not employed, and not looking for work
# 88601                                                     NaN
# 88802                                      Employed full-time
# 88816       Independent contractor, freelancer, or self-em...
# 88863                  Not employed, and not looking for work
#
#                            Country         Student  \
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 3                         Thailand              No
# 4                    United States              No
# 5                          Ukraine              No
# 6                           Canada              No
# 7                          Ukraine              No
# 8                            India             NaN
# 9                      New Zealand              No
# 10                           India              No
# 11             Antigua and Barbuda  Yes, full-time
# 12                          Canada  Yes, full-time
# 13                   United States              No
# 14                         Germany              No
# 15                           India  Yes, full-time
# 16                  United Kingdom              No
# 17                       Australia              No
# 18              Russian Federation              No
# 19                          Brazil              No
# 20                       Lithuania              No
# 21                          Canada             NaN
# 22                   United States              No
# 23                   United States              No
# 24                          Israel              No
# 25                    South Africa              No
# 26                   United States              No
# 27                        Colombia  Yes, part-time
# 28                          Turkey              No
# 29                   United States              No
# 30                     Switzerland              No
# 31                          Canada              No
# 32                   United States              No
# 33                       Argentina  Yes, full-time
# 34                       Sri Lanka              No
# 35                   United States              No
# 36                         Germany  Yes, full-time
# 37                          Canada  Yes, full-time
# 38                  Czech Republic              No
# 39                   United States              No
# 40                         Denmark  Yes, full-time
# 41                        Malaysia  Yes, full-time
# 42                      Bangladesh              No
# ...                            ...             ...
# 82789               United Kingdom              No
# 82805           Russian Federation              No
# 83000                       Brazil              No
# 83397                United States              No
# 83511                          NaN             NaN
# 83612                     Thailand             NaN
# 83648                          NaN             NaN
# 83709                    Argentina  Yes, part-time
# 83777                          NaN             NaN
# 83786                      Germany              No
# 83800                          NaN             NaN
# 83862                        India  Yes, full-time
# 84299                        India  Yes, full-time
# 84539               United Kingdom  Yes, full-time
# 85182                       Canada             NaN
# 85208                          NaN             NaN
# 85396                       Sweden              No
# 85538                          NaN             NaN
# 85642                United States              No
# 85738                       Brazil  Yes, full-time
# 85744                          NaN             NaN
# 85955                        Egypt  Yes, part-time
# 85961               United Kingdom              No
# 86012                        India              No
# 86566                  Switzerland              No
# 86638                    Australia              No
# 86806                      Nigeria  Yes, part-time
# 86980                          NaN             NaN
# 86999                          NaN             NaN
# 87352                  Netherlands              No
# 87386                        Italy  Yes, full-time
# 87739               Czech Republic  Yes, full-time
# 88062                          NaN             NaN
# 88076                          NaN             NaN
# 88182                     Pakistan             NaN
# 88212                        Spain              No
# 88282                United States              No
# 88377                       Canada              No
# 88601                          NaN             NaN
# 88802                          NaN             NaN
# 88816                          NaN             NaN
# 88863                        Spain  Yes, full-time
#
#                                                       EdLevel  \
# Respondent
# 1                                   Primary/elementary school
# 2           Secondary school (e.g. American high school, G...
# 3                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8                    Bachelor’s degree (BA, BS, B.Eng., etc.)
# 9           Some college/university study without earning ...
# 10                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11                                  Primary/elementary school
# 12          Some college/university study without earning ...
# 13                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 14                  Other doctoral degree (Ph.D, Ed.D., etc.)
# 15          Secondary school (e.g. American high school, G...
# 16                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 17                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 18                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 19          Some college/university study without earning ...
# 20                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 21                                                        NaN
# 22          Some college/university study without earning ...
# 23                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 24                                  Primary/elementary school
# 25                                           Associate degree
# 26          Some college/university study without earning ...
# 27          Some college/university study without earning ...
# 28                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 29                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 30                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 31                                  Primary/elementary school
# 32                                           Associate degree
# 33                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 34                                  Primary/elementary school
# 35                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 36          Secondary school (e.g. American high school, G...
# 37                                           Associate degree
# 38                Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 39                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 40          Secondary school (e.g. American high school, G...
# 41                   Bachelor’s degree (BA, BS, B.Eng., etc.)
# 42          Secondary school (e.g. American high school, G...
# ...                                                       ...
# 82789       Secondary school (e.g. American high school, G...
# 82805       Some college/university study without earning ...
# 83000       Secondary school (e.g. American high school, G...
# 83397                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83511                                                     NaN
# 83612             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 83648                                                     NaN
# 83709                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 83777                                                     NaN
# 83786               Other doctoral degree (Ph.D, Ed.D., etc.)
# 83800                                                     NaN
# 83862                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84299                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 84539                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 85182                                                     NaN
# 85208                                                     NaN
# 85396                      Professional degree (JD, MD, etc.)
# 85538                                                     NaN
# 85642                                        Associate degree
# 85738       Secondary school (e.g. American high school, G...
# 85744                                                     NaN
# 85955       Secondary school (e.g. American high school, G...
# 85961               Other doctoral degree (Ph.D, Ed.D., etc.)
# 86012             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 86566       Some college/university study without earning ...
# 86638       Some college/university study without earning ...
# 86806       Secondary school (e.g. American high school, G...
# 86980                                                     NaN
# 86999                                                     NaN
# 87352                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87386                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 87739             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88062                                                     NaN
# 88076                                                     NaN
# 88182       Secondary school (e.g. American high school, G...
# 88212       Secondary school (e.g. American high school, G...
# 88282       Some college/university study without earning ...
# 88377                               Primary/elementary school
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
# 88863                      Professional degree (JD, MD, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 6                                   Mathematics or statistics
# 7           Another engineering discipline (ex. civil, ele...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10                                                        NaN
# 11                                                        NaN
# 12                                  Mathematics or statistics
# 13          Computer science, computer engineering, or sof...
# 14          Computer science, computer engineering, or sof...
# 15                                                        NaN
# 16                                                        NaN
# 17          Computer science, computer engineering, or sof...
# 18          Computer science, computer engineering, or sof...
# 19          Computer science, computer engineering, or sof...
# 20          Information systems, information technology, o...
# 21                                                        NaN
# 22                                                        NaN
# 23          Information systems, information technology, o...
# 24                                                        NaN
# 25          Computer science, computer engineering, or sof...
# 26          Computer science, computer engineering, or sof...
# 27          Information systems, information technology, o...
# 28          A business discipline (ex. accounting, finance...
# 29                                                        NaN
# 30          Computer science, computer engineering, or sof...
# 31                                                        NaN
# 32          Information systems, information technology, o...
# 33          A natural science (ex. biology, chemistry, phy...
# 34                                                        NaN
# 35          Information systems, information technology, o...
# 36                                                        NaN
# 37          A social science (ex. anthropology, psychology...
# 38          Computer science, computer engineering, or sof...
# 39          Computer science, computer engineering, or sof...
# 40                                                        NaN
# 41          Information systems, information technology, o...
# 42                                                        NaN
# ...                                                       ...
# 82789                                                     NaN
# 82805                                I never declared a major
# 83000                                                     NaN
# 83397       Computer science, computer engineering, or sof...
# 83511                                                     NaN
# 83612                                                     NaN
# 83648                                                     NaN
# 83709       Computer science, computer engineering, or sof...
# 83777                                                     NaN
# 83786       Computer science, computer engineering, or sof...
# 83800                                                     NaN
# 83862                                                     NaN
# 84299                           Web development or web design
# 84539       Computer science, computer engineering, or sof...
# 85182                                                     NaN
# 85208                                                     NaN
# 85396                                                     NaN
# 85538                                                     NaN
# 85642       Information systems, information technology, o...
# 85738                                                     NaN
# 85744                                                     NaN
# 85955                                                     NaN
# 85961       Computer science, computer engineering, or sof...
# 86012       Another engineering discipline (ex. civil, ele...
# 86566       A humanities discipline (ex. literature, histo...
# 86638       Computer science, computer engineering, or sof...
# 86806                                                     NaN
# 86980                                                     NaN
# 86999                                                     NaN
# 87352       Computer science, computer engineering, or sof...
# 87386       Computer science, computer engineering, or sof...
# 87739       Computer science, computer engineering, or sof...
# 88062                                                     NaN
# 88076                                                     NaN
# 88182                                                     NaN
# 88212                                                     NaN
# 88282       Computer science, computer engineering, or sof...
# 88377                                                     NaN
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
# 88863       Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
# 6           Taken an online course in programming or softw...
# 7           Taught yourself a new language, framework, or ...
# 8           Taught yourself a new language, framework, or ...
# 9           Taken an online course in programming or softw...
# 10                                                        NaN
# 11                        Contributed to open source software
# 12          Taken an online course in programming or softw...
# 13          Taken an online course in programming or softw...
# 14          Completed an industry certification program (e...
# 15          Taken an online course in programming or softw...
# 16          Taken an online course in programming or softw...
# 17          Taken an online course in programming or softw...
# 18          Taken an online course in programming or softw...
# 19          Received on-the-job training in software devel...
# 20          Taken an online course in programming or softw...
# 21          Taught yourself a new language, framework, or ...
# 22          Taken an online course in programming or softw...
# 23          Taken an online course in programming or softw...
# 24          Taken an online course in programming or softw...
# 25          Taken an online course in programming or softw...
# 26          Taught yourself a new language, framework, or ...
# 27          Taken an online course in programming or softw...
# 28          Taken an online course in programming or softw...
# 29          Taken an online course in programming or softw...
# 30          Taught yourself a new language, framework, or ...
# 31                                                        NaN
# 32          Completed an industry certification program (e...
# 33          Taken an online course in programming or softw...
# 34          Taken an online course in programming or softw...
# 35          Taken a part-time in-person course in programm...
# 36          Taken an online course in programming or softw...
# 37          Taken a part-time in-person course in programm...
# 38          Participated in a full-time developer training...
# 39          Taken an online course in programming or softw...
# 40          Taken an online course in programming or softw...
# 41          Taken an online course in programming or softw...
# 42          Taken a part-time in-person course in programm...
# ...                                                       ...
# 82789       Taken an online course in programming or softw...
# 82805       Taken an online course in programming or softw...
# 83000       Taken an online course in programming or softw...
# 83397       Taken an online course in programming or softw...
# 83511                                                     NaN
# 83612                                                     NaN
# 83648                                                     NaN
# 83709       Taken an online course in programming or softw...
# 83777                                                     NaN
# 83786       Taught yourself a new language, framework, or ...
# 83800                                                     NaN
# 83862                             Participated in a hackathon
# 84299       Taken an online course in programming or softw...
# 84539       Taken an online course in programming or softw...
# 85182                                                     NaN
# 85208                                                     NaN
# 85396       Taken an online course in programming or softw...
# 85538                                                     NaN
# 85642       Taken an online course in programming or softw...
# 85738       Taught yourself a new language, framework, or ...
# 85744                                                     NaN
# 85955       Taught yourself a new language, framework, or ...
# 85961       Taught yourself a new language, framework, or ...
# 86012       Taught yourself a new language, framework, or ...
# 86566       Taken a part-time in-person course in programm...
# 86638                                                     NaN
# 86806                     Contributed to open source software
# 86980                                                     NaN
# 86999                                                     NaN
# 87352                                                     NaN
# 87386       Taken an online course in programming or softw...
# 87739       Taught yourself a new language, framework, or ...
# 88062                                                     NaN
# 88076                                                     NaN
# 88182       Taken an online course in programming or softw...
# 88212       Taught yourself a new language, framework, or ...
# 88282       Taught yourself a new language, framework, or ...
# 88377       Taught yourself a new language, framework, or ...
# 88601                                                     NaN
# 88802                                                     NaN
# 88816                                                     NaN
# 88863       Taken an online course in programming or softw...
#
#                                                       OrgSize  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                        100 to 499 employees
# 4                                        100 to 499 employees
# 5                                    10,000 or more employees
# 6                                                         NaN
# 7           Just me - I am a freelancer, sole proprietor, ...
# 8                                                         NaN
# 9                                          10 to 19 employees
# 10                                   10,000 or more employees
# 11                                                        NaN
# 12                                                        NaN
# 13                                         10 to 19 employees
# 14                                       100 to 499 employees
# 15                                                        NaN
# 16                                       100 to 499 employees
# 17                                         20 to 99 employees
# 18                                   1,000 to 4,999 employees
# 19                                       100 to 499 employees
# 20                                   1,000 to 4,999 employees
# 21                                                        NaN
# 22                                   10,000 or more employees
# 23                                   10,000 or more employees
# 24                                         10 to 19 employees
# 25                                              2-9 employees
# 26                                   10,000 or more employees
# 27                                                        NaN
# 28                                              2-9 employees
# 29                                   10,000 or more employees
# 30                                   1,000 to 4,999 employees
# 31                                                        NaN
# 32                                       100 to 499 employees
# 33                                   10,000 or more employees
# 34                                                        NaN
# 35                                         20 to 99 employees
# 36                                   1,000 to 4,999 employees
# 37                                       100 to 499 employees
# 38                                         10 to 19 employees
# 39                                       100 to 499 employees
# 40                                                        NaN
# 41                                              2-9 employees
# ...
# 26                                           Gay or Lesbian
# 27                                  Straight / Heterosexual
# 28                                                      NaN
# 29                                  Straight / Heterosexual
# 30                                  Straight / Heterosexual
# 31                                                      NaN
# 32                                  Straight / Heterosexual
# 33                                  Straight / Heterosexual
# 34                                                 Bisexual
# 35                                  Straight / Heterosexual
# 36                                  Straight / Heterosexual
# 37                                                      NaN
# 38                                                      NaN
# 39                                                 Bisexual
# 40                                  Bisexual;Gay or Lesbian
# 41                                                      NaN
# 42                                  Straight / Heterosexual
# ...                                                     ...
# 82789                               Straight / Heterosexual
# 82805                               Straight / Heterosexual
# 83000                               Straight / Heterosexual
# 83397                                              Bisexual
# 83511                                                   NaN
# 83612                                        Gay or Lesbian
# 83648                                                   NaN
# 83709                                                   NaN
# 83777                                                   NaN
# 83786                                                   NaN
# 83800                                                   NaN
# 83862                               Straight / Heterosexual
# 84299                                                   NaN
# 84539                                              Bisexual
# 85182                               Straight / Heterosexual
# 85208                                                   NaN
# 85396                               Straight / Heterosexual
# 85538                                                   NaN
# 85642                               Bisexual;Gay or Lesbian
# 85738                               Straight / Heterosexual
# 85744                                                   NaN
# 85955                                                   NaN
# 85961                                        Gay or Lesbian
# 86012                                                   NaN
# 86566                                                   NaN
# 86638                               Straight / Heterosexual
# 86806                                                   NaN
# 86980                                                   NaN
# 86999                                                   NaN
# 87352                                                   NaN
# 87386                               Straight / Heterosexual
# 87739                               Straight / Heterosexual
# 88062                                                   NaN
# 88076                                                   NaN
# 88182                               Straight / Heterosexual
# 88212                               Straight / Heterosexual
# 88282                               Straight / Heterosexual
# 88377                                                   NaN
# 88601                                                   NaN
# 88802                                                   NaN
# 88816                                                   NaN
# 88863                               Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 1                                                         NaN         No
# 2                                                         NaN         No
# 3                                                         NaN        Yes
# 4                                White or of European descent         No
# 5                    White or of European descent;Multiracial         No
# 6                                                  East Asian         No
# 7                                White or of European descent        Yes
# 8                                                         NaN        NaN
# 9                                White or of European descent         No
# 10                                                        NaN        Yes
# 11          Black or of African descent;East Asian;Hispani...         No
# 12                                Black or of African descent         No
# 13                               White or of European descent        Yes
# 14                               White or of European descent         No
# 15                                                        NaN        Yes
# 16                               White or of European descent         No
# 17                      Hispanic or Latino/Latina;Multiracial         No
# 18                               White or of European descent        Yes
# 19                                  Hispanic or Latino/Latina        Yes
# 20                               White or of European descent        Yes
# 21                                                        NaN         No
# 22                               White or of European descent        Yes
# 23                                Black or of African descent         No
# 24                                             Middle Eastern         No
# 25                               White or of European descent         No
# 26                                                        NaN         No
# 27                                  Hispanic or Latino/Latina         No
# 28                                                        NaN        NaN
# 29                               White or of European descent        Yes
# 30                               White or of European descent         No
# 31                                                 East Asian         No
# 32                               White or of European descent         No
# 33                                  Hispanic or Latino/Latina         No
# 34                                                South Asian        Yes
# 35                                Black or of African descent         No
# 36                               White or of European descent         No
# 37                               White or of European descent         No
# 38                                                        NaN        Yes
# 39                               White or of European descent         No
# 40                               White or of European descent         No
# 41                                                        NaN        NaN
# 42                                             Middle Eastern        NaN
# ...                                                       ...        ...
# 82789                   White or of European descent;Biracial         No
# 82805                            White or of European descent        Yes
# 83000                                                     NaN        Yes
# 83397                            White or of European descent         No
# 83511                                                     NaN        NaN
# 83612                                                     NaN        NaN
# 83648                                                     NaN        NaN
# 83709                                                     NaN         No
# 83777                                                     NaN        NaN
# 83786                            White or of European descent        Yes
# 83800                                                     NaN        NaN
# 83862                                                     NaN        Yes
# 84299                                                     NaN        NaN
# 84539                            White or of European descent         No
# 85182                                                     NaN         No
# 85208                                                     NaN        NaN
# 85396                             Black or of African descent        NaN
# 85538                                                     NaN        NaN
# 85642                            White or of European descent         No
# 85738       Hispanic or Latino/Latina;White or of European...         No
# 85744                                                     NaN        NaN
# 85955                                          Middle Eastern         No
# 85961                            White or of European descent         No
# 86012                                             South Asian        NaN
# 86566                            White or of European descent         No
# 86638                            White or of European descent        Yes
# 86806              Black or of African descent;Middle Eastern         No
# 86980                                                     NaN        NaN
# 86999                                                     NaN        NaN
# 87352                                                     NaN         No
# 87386                            White or of European descent         No
# 87739                            White or of European descent         No
# 88062                                                     NaN        NaN
# 88076                                                     NaN        NaN
# 88182                                                     NaN        Yes
# 88212                            White or of European descent         No
# 88282                                                     NaN         No
# 88377                                                     NaN         No
# 88601                                                     NaN        NaN
# 88802                                                     NaN        NaN
# 88816                                                     NaN        NaN
# 88863       Hispanic or Latino/Latina;White or of European...         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# 6                        Too long  Neither easy nor difficult
# 7           Appropriate in length  Neither easy nor difficult
# 8           Appropriate in length  Neither easy nor difficult
# 9           Appropriate in length  Neither easy nor difficult
# 10                       Too long                   Difficult
# 11          Appropriate in length                        Easy
# 12          Appropriate in length                        Easy
# 13          Appropriate in length                        Easy
# 14                      Too short                        Easy
# 15                       Too long  Neither easy nor difficult
# 16          Appropriate in length  Neither easy nor difficult
# 17          Appropriate in length                        Easy
# 18          Appropriate in length  Neither easy nor difficult
# 19                       Too long                        Easy
# 20          Appropriate in length                        Easy
# 21          Appropriate in length                        Easy
# 22          Appropriate in length                        Easy
# 23          Appropriate in length                        Easy
# 24          Appropriate in length                        Easy
# 25                      Too short  Neither easy nor difficult
# 26          Appropriate in length                        Easy
# 27          Appropriate in length  Neither easy nor difficult
# 28                            NaN                         NaN
# 29          Appropriate in length                        Easy
# 30                       Too long                        Easy
# 31                       Too long  Neither easy nor difficult
# 32          Appropriate in length  Neither easy nor difficult
# 33          Appropriate in length  Neither easy nor difficult
# 34                      Too short  Neither easy nor difficult
# 35          Appropriate in length                        Easy
# 36                       Too long  Neither easy nor difficult
# 37          Appropriate in length  Neither easy nor difficult
# 38          Appropriate in length  Neither easy nor difficult
# 39          Appropriate in length                        Easy
# 40          Appropriate in length                        Easy
# 41                       Too long  Neither easy nor difficult
# 42          Appropriate in length                        Easy
# ...                           ...                         ...
# 82789       Appropriate in length                        Easy
# 82805       Appropriate in length  Neither easy nor difficult
# 83000       Appropriate in length  Neither easy nor difficult
# 83397       Appropriate in length                        Easy
# 83511                         NaN                         NaN
# 83612                         NaN                         NaN
# 83648                         NaN                         NaN
# 83709       Appropriate in length  Neither easy nor difficult
# 83777                         NaN                         NaN
# 83786                    Too long  Neither easy nor difficult
# 83800                         NaN                         NaN
# 83862                    Too long  Neither easy nor difficult
# 84299                         NaN                         NaN
# 84539       Appropriate in length                        Easy
# 85182                    Too long                        Easy
# 85208                         NaN                         NaN
# 85396                    Too long  Neither easy nor difficult
# 85538                         NaN                         NaN
# 85642       Appropriate in length                        Easy
# 85738                   Too short                        Easy
# 85744                         NaN                         NaN
# 85955                    Too long  Neither easy nor difficult
# 85961       Appropriate in length                   Difficult
# 86012       Appropriate in length                        Easy
# 86566       Appropriate in length                        Easy
# 86638       Appropriate in length                        Easy
# 86806       Appropriate in length  Neither easy nor difficult
# 86980                         NaN                         NaN
# 86999                         NaN                         NaN
# 87352                         NaN                         NaN
# 87386       Appropriate in length                        Easy
# 87739       Appropriate in length                        Easy
# 88062                         NaN                         NaN
# 88076                         NaN                         NaN
# 88182                   Too short  Neither easy nor difficult
# 88212       Appropriate in length                        Easy
# 88282                   Too short  Neither easy nor difficult
# 88377       Appropriate in length                        Easy
# 88601                         NaN                         NaN
# 88802                         NaN                         NaN
# 88816                         NaN                         NaN
# 88863       Appropriate in length                        Easy
#
# [88883 rows x 84 columns]

# %% [markdown]
# ## Python Pandas Tutorial (Part 2): DataFrame and Series Basics - Selecting Rows and Columns
# * link https://www.youtube.com/watch?v=zmdjNSmRXF4&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=2
# * code https://github.com/CoreyMSchafer/code_snippets/tree/master/Python/Pandas/02-DataFrames

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
# 5        Yes
# 6         No
# 7        Yes
# 8        Yes
# 9        Yes
# 10       Yes
# 11        No
# 12       Yes
# 13       Yes
# 14       Yes
# 15       Yes
# 16       Yes
# 17       Yes
# 18       Yes
# 19        No
# 20       Yes
# 21       Yes
# 22       Yes
# 23       Yes
# 24        No
# 25       Yes
# 26       Yes
# 27       Yes
# 28       Yes
# 29        No
# 30        No
# 31        No
# 32        No
# 33       Yes
# 34        No
# 35       Yes
# 36       Yes
# 37       Yes
# 38       Yes
# 39       Yes
# 40       Yes
# 41       Yes
#         ...
# 88841    Yes
# 88842    Yes
# 88843     No
# 88844    Yes
# 88845     No
# 88846    Yes
# 88847     No
# 88848    Yes
# 88849     No
# 88850     No
# 88851     No
# 88852    Yes
# 88853    Yes
# 88854    Yes
# 88855     No
# 88856     No
# 88857     No
# 88858     No
# 88859     No
# 88860    Yes
# 88861     No
# 88862    Yes
# 88863    Yes
# 88864    Yes
# 88865    Yes
# 88866    Yes
# 88867    Yes
# 88868     No
# 88869     No
# 88870    Yes
# 88871    Yes
# 88872    Yes
# 88873     No
# 88874     No
# 88875    Yes
# 88876     No
# 88877    Yes
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.loc[0:2, 'Hobbyist':'Employment']
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
person = {
    "first": "Corey", 
    "last": "Schafer", 
    "email": "CoreyMSchafer@gmail.com"
}

# %%
people = {
    "first": ["Corey"], 
    "last": ["Schafer"], 
    "email": ["CoreyMSchafer@gmail.com"]
}

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
people['email']
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
df_exa = pd.DataFrame(people)

# %%
df_exa
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_exa['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df_exa.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
# 根据index找对应未知的值
df_exa.iloc[[0, 1], 2]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
# 根据行index和列名称找对应未知的值
df_exa.loc[[0, 1], ['email', 'last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe

# %% [markdown]
# ## Python Pandas Tutorial (Part 3): Indexes - How to Set, Reset, and Use Indexes
# * link https://www.youtube.com/watch?v=W9XjRYFkkyw&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=3
# * code http://bit.ly/Pandas-03

# %%
df_exa.set_index('email', inplace=True)

# %%
df_exa
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
df_exa.index
# Out:
# Index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')

# %%
df_exa.loc['CoreyMSchafer@gmail.com', 'last']
# Out:
# 'Schafer'

# %%
df_exa.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
df_exa.reset_index(inplace=True)
df_exa
# Out:
#                      email  first     last
# 0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1        JaneDoe@email.com   Jane      Doe
# 2        JohnDoe@email.com   John      Doe

# %% [markdown]
# ## Python Pandas Tutorial (Part 4): Filtering - Using Conditionals to Filter Rows and Columns
# * link https://www.youtube.com/watch?v=Lw2rlcxScZY&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=4
# * code http://bit.ly/Pandas-04

# %%
filt = (df_exa['last'] == 'Schafer') | (df_exa['first'] == 'John')

# %%
df_exa.loc[~filt, 'email'] # 不选择满足条件的
# Out:
# 1    JaneDoe@email.com
# Name: email, dtype: object

# %% [markdown]
# ## Python Pandas Tutorial (Part 5): Updating Rows and Columns - Modifying Data Within DataFrames
# * link https://www.youtube.com/watch?v=DCDe29sIKcE&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=5
# * code http://bit.ly/Pandas-05

# %%
people = {
    "first": ["Corey", 'Jane', 'John'], 
    "last": ["Schafer", 'Doe', 'Doe'], 
    "email": ["CoreyMSchafer@gmail.com", 'JaneDoe@email.com', 'JohnDoe@email.com']
}

# %%
df_exa = pd.DataFrame(people)

# %%
df_exa.columns = ['first_name', 'last_name', 'email']

# %%
df_exa
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df_exa.columns = [x.lower() for x in df_exa.columns]
df_exa
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df_exa.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
df_exa.loc[2] = ['John', 'Smith', 'JohnSmith@email.com']
df_exa
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
df_exa.loc[2, ['last', 'email']] = ['Doe', 'JohnDoe@email.com']
df_exa
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_exa.loc[2, 'last'] = 'Smith'
df_exa
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith        JohnDoe@email.com

# %%
df_exa.at[2, 'last'] = 'Doe'
df_exa
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
filt = (df_exa['email'] == 'JohnDoe@email.com')
df_exa[filt]['last'] = 'Smith'
# Out:
# /Users/olivia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_exa['email'] = df_exa['email'].str.lower()
df_exa
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
df_exa['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df_exa['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df_exa['email'] = df_exa['email'].apply(lambda x: x.lower())
df_exa
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
df_exa['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df_exa.apply(len, axis='columns') ##???
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df_exa['email'])
# Out:
# 3

# %%
df_exa.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df_exa.apply(lambda x: x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df_exa.applymap(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
df_exa.applymap(str.lower)
# Out:
#    first     last                    email
# 0  corey  schafer  coreymschafer@gmail.com
# 1   jane      doe        janedoe@email.com
# 2   john      doe        johndoe@email.com

# %%
df_exa['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: object

# %%
df_exa['first'] = df_exa['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})

# %%
df_exa
# Out:
#    first     last                    email
# 0  Chris  Schafer  coreymschafer@gmail.com
# 1   Mary      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com
