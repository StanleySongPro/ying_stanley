# %%
for n in range(2,10):
    primes_lst = []
    comlst = []
    for i in range(2,n):
        if n % i == 0:
            print(True)
        else:
            print(n)
# Out:
# 3
# True
# 4
# 5
# 5
# 5
# True
# True
# 6
# 6
# 7
# 7
# 7
# 7
# 7
# True
# 8
# True
# 8
# 8
# 8
# 9
# True
# 9
# 9
# 9
# 9
# 9

# %%
def is_prime(n):
    
    if n == 1:

# %%
primes = []
composite = []
for possiblePrime in range(6598730000, 6598739999):
    
    # Assume number is prime until shown it is not. 
    isPrime = True
    for num in range(2, possiblePrime):
        if possiblePrime % num == 0:
            isPrime = False
      
    if isPrime:
        primes.append(possiblePrime)
    else:
        composite.append(possiblePrime)
# print(primes)
# print(composite)

res_lst = []
for p in primes:
    for q in primes:
        for z in composite:
            if p*q == z:
                res_lst.append(z)
                res = list(dict.fromkeys(res_lst))
                res.sort()
print(res[60])

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r'C:\Users\Zhou YingYing\Desktop\Python_basics\Data_Analysis\data_for_course\zl4.xlsx')

# %%
df.loc[0]
# Out:
# Unnamed: 0                                                                  0
# 爬取时间(__time)                                              2019-01-30 16:30:59
# 爬取链接(__url)                 http://jobs.zhaopin.com/CC461701480J0009910271...
# 职位名称(title)                                                         机构负责人（重庆）
# 发布时间(release_date)                                        2019-01-25 19:24:32
# 公司名称(cp_name)                                                 天津市中永诺信投资管理有限公司
# 薪资(pay)                                                        10001-15000元/月
# 城市(city)                                                                   重庆
# 工作经验(exp)                                                                1-3年
# 学历要求(edu)                                                                  大专
# 招聘人数(recruiting_numbers)                                                  招1人
# 职位亮点(selling_points)                '五险一金,年底双薪,节日福利,周末双休,带薪年假,高温补贴,采暖补贴,弹性工作'
# ...

# %%
df.head()
# Out:
#    Unnamed: 0         爬取时间(__time)  \
# 0           0  2019-01-30 16:30:59
# 1           1  2019-01-30 20:47:01
# 2           2  2019-01-30 14:37:45
# 3           3  2019-01-30 19:10:46
# 4           4  2019-01-29 20:53:06
#
#                                          爬取链接(__url) 职位名称(title)  \
# 0  http://jobs.zhaopin.com/CC461701480J0009910271...   机构负责人（重庆）
# 1  http://jobs.zhaopin.com/CC199156422J0006373340...        市场经理
# 2  http://jobs.zhaopin.com/CC146668482J0029890120...        内控经理
# 3  http://jobs.zhaopin.com/CC320096619J0017306260...       工艺工程师
# 4  http://jobs.zhaopin.com/CC214207719J0019137830...       采煤技术员
#
#     发布时间(release_date)       公司名称(cp_name)         薪资(pay) 城市(city) 工作经验(exp)  \
# 0  2019-01-25 19:24:32     天津市中永诺信投资管理有限公司  10001-15000元/月       重庆      1-3年
# 1  2019-01-30 14:49:06  成都市川豪装饰有限责任公司贵阳分公司  20001-30000元/月       贵阳      1-3年
# 2  2019-01-16 10:05:56      浙江中建网络科技股份有限公司   8000-15000元/月       唐山      3-5年
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30280 entries, 0 to 30279
# Data columns (total 17 columns):
# Unnamed: 0                  30280 non-null int64
# 爬取时间(__time)                30280 non-null object
# 爬取链接(__url)                 30280 non-null object
# 职位名称(title)                 30280 non-null object
# 发布时间(release_date)          30280 non-null object
# 公司名称(cp_name)               30280 non-null object
# 薪资(pay)                     30280 non-null object
# 城市(city)                    30185 non-null object
# 工作经验(exp)                   30271 non-null object
# 学历要求(edu)                   30269 non-null object
# 招聘人数(recruiting_numbers)    30272 non-null object
# 职位亮点(selling_points)        30280 non-null object
# 职位信息(infos)                 30280 non-null object
# 公司信息链接(web)                 30280 non-null object
# 工作地址(workplace)             30256 non-null object
# 公司信息(cp_infos)              30280 non-null object
# Unnamed: 15                 0 non-null float64
# ...

# %%
df.loc[0:3]
# Out:
#    Unnamed: 0         爬取时间(__time)  \
# 0           0  2019-01-30 16:30:59
# 1           1  2019-01-30 20:47:01
# 2           2  2019-01-30 14:37:45
# 3           3  2019-01-30 19:10:46
#
#                                          爬取链接(__url) 职位名称(title)  \
# 0  http://jobs.zhaopin.com/CC461701480J0009910271...   机构负责人（重庆）
# 1  http://jobs.zhaopin.com/CC199156422J0006373340...        市场经理
# 2  http://jobs.zhaopin.com/CC146668482J0029890120...        内控经理
# 3  http://jobs.zhaopin.com/CC320096619J0017306260...       工艺工程师
#
#     发布时间(release_date)       公司名称(cp_name)         薪资(pay) 城市(city) 工作经验(exp)  \
# 0  2019-01-25 19:24:32     天津市中永诺信投资管理有限公司  10001-15000元/月       重庆      1-3年
# 1  2019-01-30 14:49:06  成都市川豪装饰有限责任公司贵阳分公司  20001-30000元/月       贵阳      1-3年
# 2  2019-01-16 10:05:56      浙江中建网络科技股份有限公司   8000-15000元/月       唐山      3-5年
# 3  2019-01-29 13:15:17        江苏亚威机床股份有限公司   5000-10000元/月       扬州     5-10年
#
#   学历要求(edu) 招聘人数(recruiting_numbers)  \
# ...

# %%
data=df.loc[0]

# %%
df.tail(1)
# Out:
#        Unnamed: 0         爬取时间(__time)  \
# 30279       30279  2019-01-30 15:26:42
#
#                                              爬取链接(__url) 职位名称(title)  \
# 30279  http://jobs.zhaopin.com/CC644788880J0030487640...     室内助理设计师
#
#         发布时间(release_date)         公司名称(cp_name)       薪资(pay) 城市(city)  \
# 30279  2019-01-29 13:04:36  北京多彩猫装饰工程设计有限公司宿迁分公司  3000-5000元/月       宿迁
#
#       工作经验(exp) 学历要求(edu) 招聘人数(recruiting_numbers)  \
# 30279      1-3年        大专                      招6人
#
#                            职位亮点(selling_points)  \
# 30279  '全勤奖,加班补助,交通补助,带薪年假,节日福利,员工旅游,项目奖金,绩效奖金'
#
#                                              职位信息(infos)  \
# 30279  职位描述1、1年工作经验，室内设计相关专业毕业，吃苦耐劳。2、具有较强创意和审美，独特的色彩...
#
#                                       公司信息链接(web)      工作地址(workplace)  \
# 30279  http://company.zhaopin.com/CZ644788880.htm  宿城区富康路霸王装饰城东门南侧292号
#
#                 公司信息(cp_infos)  Unnamed: 15
# 30279  ["保密","民营","保密","\n\n"]          NaN

# %%
df.append(data)
# Out:
#        Unnamed: 0         爬取时间(__time)  \
# 0               0  2019-01-30 16:30:59
# 1               1  2019-01-30 20:47:01
# 2               2  2019-01-30 14:37:45
# 3               3  2019-01-30 19:10:46
# 4               4  2019-01-29 20:53:06
# 5               5  2019-01-30 18:43:18
# 6               6  2019-01-30 13:23:47
# 7               7  2019-01-30 14:17:34
# 8               8  2019-01-30 16:40:09
# 9               9  2019-01-30 21:05:20
# 10             10  2019-01-30 17:21:21
# 11             11  2019-01-30 18:13:23
# 12             12  2019-01-30 16:52:47
# 13             13  2019-01-30 21:12:07
# 14             14  2019-01-30 18:26:44
# 15             15  2019-01-30 15:01:37
# 16             16  2019-01-30 19:43:17
# 17             17  2019-01-30 21:08:34
# 18             18  2019-01-30 15:26:19
# 19             19  2019-01-30 19:51:04
# 20             20  2019-01-30 17:32:09
# 21             21  2019-01-30 18:47:53
# 22             22  2019-01-30 19:45:55
# ...

# %%
df.tail(2)
# Out:
#        Unnamed: 0         爬取时间(__time)  \
# 30278       30278  2019-01-30 19:46:13
# 30279       30279  2019-01-30 15:26:42
#
#                                              爬取链接(__url) 职位名称(title)  \
# 30278        http://jobs.zhaopin.com/183890924253778.htm      学术推广专员
# 30279  http://jobs.zhaopin.com/CC644788880J0030487640...     室内助理设计师
#
#         发布时间(release_date)         公司名称(cp_name)       薪资(pay) 城市(city)  \
# 30278  2018-12-27 08:45:48          四川科伦药业股份有限公司            面议       郑州
# 30279  2019-01-29 13:04:36  北京多彩猫装饰工程设计有限公司宿迁分公司  3000-5000元/月       宿迁
#
#       工作经验(exp) 学历要求(edu) 招聘人数(recruiting_numbers)  \
# 30278      1-3年        大专                      招5人
# 30279      1-3年        大专                      招6人
#
#                            职位亮点(selling_points)  \
# 30278      '节日福利,五险一金,周末双休,绩效奖金,带薪年假,定期体检,员工旅游'
# 30279  '全勤奖,加班补助,交通补助,带薪年假,节日福利,员工旅游,项目奖金,绩效奖金'
#
#                                              职位信息(infos)  \
# ...

# %%
df.drop(0)
# Out:
#        Unnamed: 0         爬取时间(__time)  \
# 1               1  2019-01-30 20:47:01
# 2               2  2019-01-30 14:37:45
# 3               3  2019-01-30 19:10:46
# 4               4  2019-01-29 20:53:06
# 5               5  2019-01-30 18:43:18
# 6               6  2019-01-30 13:23:47
# 7               7  2019-01-30 14:17:34
# 8               8  2019-01-30 16:40:09
# 9               9  2019-01-30 21:05:20
# 10             10  2019-01-30 17:21:21
# 11             11  2019-01-30 18:13:23
# 12             12  2019-01-30 16:52:47
# 13             13  2019-01-30 21:12:07
# 14             14  2019-01-30 18:26:44
# 15             15  2019-01-30 15:01:37
# 16             16  2019-01-30 19:43:17
# 17             17  2019-01-30 21:08:34
# 18             18  2019-01-30 15:26:19
# 19             19  2019-01-30 19:51:04
# 20             20  2019-01-30 17:32:09
# 21             21  2019-01-30 18:47:53
# 22             22  2019-01-30 19:45:55
# 23             23  2019-01-29 21:04:18
# ...

# %%
df['NO']=range(len(df))

# %%
df.loc[2]
# Out:
# Unnamed: 0                                                                  2
# 爬取时间(__time)                                              2019-01-30 14:37:45
# 爬取链接(__url)                 http://jobs.zhaopin.com/CC146668482J0029890120...
# 职位名称(title)                                                              内控经理
# 发布时间(release_date)                                        2019-01-16 10:05:56
# 公司名称(cp_name)                                                  浙江中建网络科技股份有限公司
# 薪资(pay)                                                         8000-15000元/月
# 城市(city)                                                                   唐山
# 工作经验(exp)                                                                3-5年
# 学历要求(edu)                                                                  本科
# 招聘人数(recruiting_numbers)                                                  招1人
# 职位亮点(selling_points)                                  '全勤奖,餐补,定期体检,五险一金,带薪年假'
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '爬取时间(__time)', '爬取链接(__url)', '职位名称(title)',
#        '发布时间(release_date)', '公司名称(cp_name)', '薪资(pay)', '城市(city)',
#        '工作经验(exp)', '学历要求(edu)', '招聘人数(recruiting_numbers)',
#        '职位亮点(selling_points)', '职位信息(infos)', '公司信息链接(web)', '工作地址(workplace)',
#        '公司信息(cp_infos)', 'Unnamed: 15', 'NO'],
#       dtype='object')

# %%
df=df[['Unnamed: 0', 'NO', '爬取时间(__time)', '爬取链接(__url)', '职位名称(title)',
       '发布时间(release_date)', '公司名称(cp_name)', '薪资(pay)', '城市(city)',
       '工作经验(exp)', '学历要求(edu)', '招聘人数(recruiting_numbers)',
       '职位亮点(selling_points)', '职位信息(infos)', '公司信息链接(web)', '工作地址(workplace)',
       '公司信息(cp_infos)', 'Unnamed: 15']]

# %%
df.head(1)
# Out:
#    Unnamed: 0  NO         爬取时间(__time)  \
# 0           0   0  2019-01-30 16:30:59
#
#                                          爬取链接(__url) 职位名称(title)  \
# 0  http://jobs.zhaopin.com/CC461701480J0009910271...   机构负责人（重庆）
#
#     发布时间(release_date)    公司名称(cp_name)         薪资(pay) 城市(city) 工作经验(exp)  \
# 0  2019-01-25 19:24:32  天津市中永诺信投资管理有限公司  10001-15000元/月       重庆      1-3年
#
#   学历要求(edu) 招聘人数(recruiting_numbers)  \
# 0        大专                      招1人
#
#                         职位亮点(selling_points)  \
# 0  '五险一金,年底双薪,节日福利,周末双休,带薪年假,高温补贴,采暖补贴,弹性工作'
#
#                                          职位信息(infos)  \
# 0  职位描述岗位职责：1.&nbsp;依据职场整体战略，组织制定营销战略，配合市场销售推广工作；...
#
#                                   公司信息链接(web) 工作地址(workplace)  \
# 0  http://company.zhaopin.com/CZ461701480.htm           大坪虎头岩
#
#                                       公司信息(cp_infos)  Unnamed: 15
# 0  ["基金/证券/期货/投资","民营","1000-9999人","http://www.c...          NaN

# %%
df.loc[[0,3,3,5,7,8,15],['No','职位名称(title)','发布时间(release_date']]
# Out:
# C:\Users\Zhou YingYing\python37\lib\site-packages\pandas\core\indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#     No            职位名称(title)  发布时间(release_date
# 0  NaN              机构负责人（重庆）                NaN
# 3  NaN                  工艺工程师                NaN
# 3  NaN                  工艺工程师                NaN
# 5  NaN  课程顾问 月薪入万+交通便利+免费英语培训                NaN
# 7  NaN               生鲜超市储备干部                NaN
# 8  NaN              整备洗车工 包吃住                NaN
# 15 NaN                 人力资源专员                NaN

# %%
df['职位名称(title)'] == '人力资源专员'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15        True
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 30250    False
# 30251    False
# 30252    False
# 30253    False
# 30254    False
# 30255    False
# 30256    False
# 30257    False
# 30258    False
# 30259    False
# 30260    False
# 30261    False
# 30262    False
# 30263    False
# 30264    False
# 30265    False
# 30266    False
# 30267    False
# 30268    False
# 30269    False
# 30270    False
# 30271    False
# 30272    False
# 30273    False
# 30274    False
# 30275    False
# 30276    False
# ...

# %%
df[df['职位名称(title)'] == '人力资源专员']
# Out:
#        Unnamed: 0     NO         爬取时间(__time)  \
# 15             15     15  2019-01-30 15:01:37
# 4128         4128   4128  2019-01-29 20:17:10
# 5731         5731   5731  2019-01-29 20:05:28
# 12329       12329  12329  2019-01-30 13:50:23
# 24101       24101  24101  2019-01-29 18:56:57
# 28665       28665  28665  2019-01-29 19:18:06
#
#                                              爬取链接(__url) 职位名称(title)  \
# 15     http://jobs.zhaopin.com/CC165148824J0007541251...      人力资源专员
# 4128   http://jobs.zhaopin.com/CC260651482J0010095111...      人力资源专员
# 5731   http://jobs.zhaopin.com/CC365268081J0007059801...      人力资源专员
# 12329  http://jobs.zhaopin.com/CC330953280J0030278770...      人力资源专员
# 24101  http://jobs.zhaopin.com/CC486109235J0010843690...      人力资源专员
# 28665        http://jobs.zhaopin.com/671202728250103.htm      人力资源专员
#
#         发布时间(release_date)     公司名称(cp_name)        薪资(pay) 城市(city)  \
# 15     2019-01-28 17:32:32  后浪出版咨询(北京)有限责任公司   4001-6000元/月       北京
# ...

# %%
df1=df.dropna()

# %%
df.dropna(subset=['学历要求(edu)'])
# Out:
#        Unnamed: 0     NO         爬取时间(__time)  \
# 0               0      0  2019-01-30 16:30:59
# 1               1      1  2019-01-30 20:47:01
# 2               2      2  2019-01-30 14:37:45
# 3               3      3  2019-01-30 19:10:46
# 4               4      4  2019-01-29 20:53:06
# 5               5      5  2019-01-30 18:43:18
# 6               6      6  2019-01-30 13:23:47
# 7               7      7  2019-01-30 14:17:34
# 8               8      8  2019-01-30 16:40:09
# 9               9      9  2019-01-30 21:05:20
# 10             10     10  2019-01-30 17:21:21
# 11             11     11  2019-01-30 18:13:23
# 12             12     12  2019-01-30 16:52:47
# 13             13     13  2019-01-30 21:12:07
# 14             14     14  2019-01-30 18:26:44
# 15             15     15  2019-01-30 15:01:37
# 16             16     16  2019-01-30 19:43:17
# 17             17     17  2019-01-30 21:08:34
# 18             18     18  2019-01-30 15:26:19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30280 entries, 0 to 30279
# Data columns (total 18 columns):
# Unnamed: 0                  30280 non-null int64
# NO                          30280 non-null int32
# 爬取时间(__time)                30280 non-null object
# 爬取链接(__url)                 30280 non-null object
# 职位名称(title)                 30280 non-null object
# 发布时间(release_date)          30280 non-null object
# 公司名称(cp_name)               30280 non-null object
# 薪资(pay)                     30280 non-null object
# 城市(city)                    30185 non-null object
# 工作经验(exp)                   30271 non-null object
# 学历要求(edu)                   30269 non-null object
# 招聘人数(recruiting_numbers)    30272 non-null object
# 职位亮点(selling_points)        30280 non-null object
# 职位信息(infos)                 30280 non-null object
# 公司信息链接(web)                 30280 non-null object
# 工作地址(workplace)             30256 non-null object
# 公司信息(cp_infos)              30280 non-null object
# ...

# %%
df=df.drop(columns=['Unnamed: 15'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30280 entries, 0 to 30279
# Data columns (total 17 columns):
# Unnamed: 0                  30280 non-null int64
# NO                          30280 non-null int32
# 爬取时间(__time)                30280 non-null object
# 爬取链接(__url)                 30280 non-null object
# 职位名称(title)                 30280 non-null object
# 发布时间(release_date)          30280 non-null object
# 公司名称(cp_name)               30280 non-null object
# 薪资(pay)                     30280 non-null object
# 城市(city)                    30185 non-null object
# 工作经验(exp)                   30271 non-null object
# 学历要求(edu)                   30269 non-null object
# 招聘人数(recruiting_numbers)    30272 non-null object
# 职位亮点(selling_points)        30280 non-null object
# 职位信息(infos)                 30280 non-null object
# 公司信息链接(web)                 30280 non-null object
# 工作地址(workplace)             30256 non-null object
# 公司信息(cp_infos)              30280 non-null object
# ...

# %%
df=df.drop(index=[0,1,2])
df.head()
# Out:
#    Unnamed: 0  NO         爬取时间(__time)  \
# 3           3   3  2019-01-30 19:10:46
# 4           4   4  2019-01-29 20:53:06
# 5           5   5  2019-01-30 18:43:18
# 6           6   6  2019-01-30 13:23:47
# 7           7   7  2019-01-30 14:17:34
#
#                                          爬取链接(__url)            职位名称(title)  \
# 3  http://jobs.zhaopin.com/CC320096619J0017306260...                  工艺工程师
# 4  http://jobs.zhaopin.com/CC214207719J0019137830...                  采煤技术员
# 5        http://jobs.zhaopin.com/273812037250265.htm  课程顾问 月薪入万+交通便利+免费英语培训
# 6  http://jobs.zhaopin.com/CC141236214J0015990410...           生产班组长（储能、电池）
# 7        http://jobs.zhaopin.com/337958227250298.htm               生鲜超市储备干部
#
#     发布时间(release_date) 公司名称(cp_name)        薪资(pay) 城市(city) 工作经验(exp)  \
# 3  2019-01-29 13:15:17  江苏亚威机床股份有限公司  5000-10000元/月       扬州     5-10年
# 4  2019-01-29 19:01:00  陕西恒源投资集团有限公司   5500-7000元/月       榆林      经验不限
# ...

# %%
df.index=range(len(df))

# %%
df.head()
# Out:
#    Unnamed: 0  NO         爬取时间(__time)  \
# 0           3   3  2019-01-30 19:10:46
# 1           4   4  2019-01-29 20:53:06
# 2           5   5  2019-01-30 18:43:18
# 3           6   6  2019-01-30 13:23:47
# 4           7   7  2019-01-30 14:17:34
#
#                                          爬取链接(__url)            职位名称(title)  \
# 0  http://jobs.zhaopin.com/CC320096619J0017306260...                  工艺工程师
# 1  http://jobs.zhaopin.com/CC214207719J0019137830...                  采煤技术员
# 2        http://jobs.zhaopin.com/273812037250265.htm  课程顾问 月薪入万+交通便利+免费英语培训
# 3  http://jobs.zhaopin.com/CC141236214J0015990410...           生产班组长（储能、电池）
# 4        http://jobs.zhaopin.com/337958227250298.htm               生鲜超市储备干部
#
#     发布时间(release_date) 公司名称(cp_name)        薪资(pay) 城市(city) 工作经验(exp)  \
# 0  2019-01-29 13:15:17  江苏亚威机床股份有限公司  5000-10000元/月       扬州     5-10年
# 1  2019-01-29 19:01:00  陕西恒源投资集团有限公司   5500-7000元/月       榆林      经验不限
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30277 entries, 0 to 30276
# Data columns (total 17 columns):
# Unnamed: 0                  30277 non-null int64
# NO                          30277 non-null int32
# 爬取时间(__time)                30277 non-null object
# 爬取链接(__url)                 30277 non-null object
# 职位名称(title)                 30277 non-null object
# 发布时间(release_date)          30277 non-null object
# 公司名称(cp_name)               30277 non-null object
# 薪资(pay)                     30277 non-null object
# 城市(city)                    30182 non-null object
# 工作经验(exp)                   30268 non-null object
# 学历要求(edu)                   30266 non-null object
# 招聘人数(recruiting_numbers)    30269 non-null object
# 职位亮点(selling_points)        30277 non-null object
# 职位信息(infos)                 30277 non-null object
# 公司信息链接(web)                 30277 non-null object
# 工作地址(workplace)             30253 non-null object
# 公司信息(cp_infos)              30277 non-null object
# ...

# %%
df['工作地址(workplace)'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 30247    False
# 30248    False
# 30249    False
# 30250    False
# 30251    False
# 30252    False
# 30253    False
# 30254    False
# 30255    False
# 30256    False
# 30257    False
# 30258    False
# 30259    False
# 30260    False
# 30261    False
# 30262    False
# 30263    False
# 30264    False
# 30265    False
# 30266    False
# 30267    False
# 30268    False
# 30269    False
# 30270    False
# 30271    False
# 30272    False
# 30273    False
# ...

# %%
df[df['工作地址(workplace)'].isnull()]
# Out:
#        Unnamed: 0     NO         爬取时间(__time)  \
# 1562         1565   1565  2019-01-30 19:59:09
# 2754         2757   2757  2019-01-30 18:35:33
# 3106         3109   3109  2019-01-30 15:57:16
# 4249         4252   4252  2019-01-30 14:36:22
# 6616         6619   6619  2019-01-30 15:16:41
# 7312         7315   7315  2019-01-30 18:12:21
# 10208       10211  10211  2019-01-30 20:31:27
# 10480       10483  10483  2019-01-30 14:22:29
# 10680       10683  10683  2019-01-30 19:01:49
# 11248       11251  11251  2019-01-30 06:56:16
# 12208       12211  12211  2019-01-30 19:53:36
# 15157       15160  15160  2019-01-30 16:39:52
# 17267       17270  17270  2019-01-30 15:20:25
# 17383       17386  17386  2019-01-30 17:55:12
# 18405       18408  18408  2019-01-30 20:36:35
# 18440       18443  18443  2019-01-30 18:14:55
# 20863       20866  20866  2019-01-30 20:15:51
# 23079       23082  23082  2019-01-30 20:07:21
# 24726       24729  24729  2019-01-30 19:39:41
# ...

# %%
df['工作地址(workplace)']=df['工作地址(workplace)'].fillna('None')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30277 entries, 0 to 30276
# Data columns (total 17 columns):
# Unnamed: 0                  30277 non-null int64
# NO                          30277 non-null int32
# 爬取时间(__time)                30277 non-null object
# 爬取链接(__url)                 30277 non-null object
# 职位名称(title)                 30277 non-null object
# 发布时间(release_date)          30277 non-null object
# 公司名称(cp_name)               30277 non-null object
# 薪资(pay)                     30277 non-null object
# 城市(city)                    30182 non-null object
# 工作经验(exp)                   30268 non-null object
# 学历要求(edu)                   30266 non-null object
# 招聘人数(recruiting_numbers)    30269 non-null object
# 职位亮点(selling_points)        30277 non-null object
# 职位信息(infos)                 30277 non-null object
# 公司信息链接(web)                 30277 non-null object
# 工作地址(workplace)             30277 non-null object
# 公司信息(cp_infos)              30277 non-null object
# ...

# %%
df.index=range(len(df))

# %%
df['NO']=range(len(df))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'NO', '爬取时间(__time)', '爬取链接(__url)', '职位名称(title)',
#        '发布时间(release_date)', '公司名称(cp_name)', '薪资(pay)', '城市(city)',
#        '工作经验(exp)', '学历要求(edu)', '招聘人数(recruiting_numbers)',
#        '职位亮点(selling_points)', '职位信息(infos)', '公司信息链接(web)', '工作地址(workplace)',
#        '公司信息(cp_infos)'],
#       dtype='object')

# %%
df1=df[['NO', '爬取时间(__time)', '爬取链接(__url)', '职位名称(title)',
       '发布时间(release_date)', '公司名称(cp_name)', '薪资(pay)', '城市(city)',
       '工作经验(exp)', '学历要求(edu)', '招聘人数(recruiting_numbers)']]

# %%
df2=df[['NO', '职位亮点(selling_points)', '职位信息(infos)', '公司信息链接(web)', '工作地址(workplace)',
       '公司信息(cp_infos)']]

# %%
df1.to_excel(r'C:\Users\Zhou YingYing\Desktop\Python_basics\Data_Analysis\data_for_course\zl_positions.xlsx')

# %%
df2.to_excel(r'C:\Users\Zhou YingYing\Desktop\Python_basics\Data_Analysis\data_for_course\zl_companies.xlsx')
